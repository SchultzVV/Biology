# %%
import glob;import os;import cv2;import matplotlib.image as mpimg
import numpy as np;import pickle;import sys as s 
import random as rd
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # Dataset
#
# ## primeira ideia
#
# A ideia é criar um dataset separado no meio, se for dado da primeira metade ela retorna 1 e se for dado da segunda metade ela retorna 0.

# %%
from pandas_ods_reader import read_ods
sheet = "sheet_name"
df = read_ods('data_without_low_data.ods', headers=True)# , sheet)
print(type(df))
sheets=df.keys()
cells=[]
print(np.shape(sheets))
for i in sheets:
    cells.append(i)
#sheets.remove('time')
#print(cells)
cells.remove('time')
print(cells)
#print(df[cells[0]])
#print(df[cells[0]][0])
#x=np.zeros(len(df[cells[0]]))
#y=np.linspace(0,len(x),len(x))#,len(df[cells[0]]))
o=1
for i in cells:
    print(o)
    o+=1
    y=np.array(df[i])
    y=y/max(y)
    print(max(y))
    x=np.linspace(0,len(y),len(y))
    print(len(x))
#x[i]=i
    plt.plot(x,y)
    plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (45,)
# ['cell 30', 'cell 28', 'cell 44', 'cell 65', 'cell 69', 'cell 41', 'cell 26', 'cell 17', 'cell 23', 'cell 53', 'cell 20', 'cell 28 2', 'cell 40', 'cell 69 2', 'cell 85', 'cell 14', 'cell 32', 'cell 62', 'cell 22', 'cell 16', 'cell 11', 'cell 15', 'cell 2', 'cell 30 2', 'cell 61', 'cell 40 2', 'cell 86', 'cell 77', 'cell 72', 'cell 41.1', 'cell 26.1', 'cell 64', 'cell 57', 'cell 77 2', 'cell 22 2', 'cell 80 2', 'cell 25', 'cell 126', 'cell 76', 'cell 65 2', 'cell 105', 'cell 72 2', 'cell 93', 'cell 129']
# 1
# 1.0
# 145
# 2
# 1.0
# 145
# 3
# 1.0
# 145
# 4
# 1.0
# 145
# 5
# 1.0
# 145
# 6
# 1.0
# 145
# 7
# 1.0
# 145
# 8
# 1.0
# 145
# 9
# 1.0
# 145
# 10
# 1.0
# 145
# 11
# 1.0
# 145
# 12
# 1.0
# 145
# 13
# 1.0
# 145
# 14
# 1.0
# 145
# 15
# 1.0
# 145
# 16
# 1.0
# 145
# 17
# 1.0
# 145
# 18
# 1.0
# 145
# 19
# 1.0
# 145
# 20
# 1.0
# 145
# 21
# 1.0
# 145
# 22
# 1.0
# 145
# 23
# 1.0
# 145
# 24
# 1.0
# 145
# 25
# 1.0
# 145
# 26
# 1.0
# 145
# 27
# ...

# %%
sheet = "sheet_name"
df = read_ods('data.ods', headers=True)# , sheet)
print(type(df))
sheets=df.keys()
cells=[]
print(np.shape(sheets))
for i in sheets:
    cells.append(i)
#sheets.remove('time')
print(cells)
cells.remove('time')
print(cells)
print(df[cells[0]])
print(df[cells[0]][0])
for i in cells:
    print()
#df = read_ods(base_path, 1, headers=False)
#df = read_ods(base_path, 1, columns=["col1", "col2", "col3"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (51,)
# ['time', 'cell 30', 'cell 28', 'cell 44', 'cell 65', 'cell 69', 'cell 41', 'cell 26', 'cell 17', 'cell 23', 'cell 53', 'cell 20', 'cell 28 2', 'cell 40', 'cell 69 2', 'cell 85', ' cell 47', 'cell 89', 'cell 80', 'cell 54', 'cell 14', 'cell 32', 'cell 62', 'cell 22', 'cell 16', 'cell 11', 'cell 15', 'cell 21', 'cell 2', 'cell 30 2', 'cell 61', 'cell 40 2', 'cell 86', 'cell 77', 'cell 72', 'cell 41.1', 'cell 26.1', 'Cell 44 2', 'cell 64', 'cell 57', 'cell 77 2', 'cell 22 2', 'cell 80 2', 'cell 25', 'cell 126', 'cell 76', 'cell 65 2', 'cell 105', 'cell 72 2', 'cell 93', 'cell 129']
# ...

# %%
def x2(x):
    a=x**2
    #a=a/100
    return a
def seno(x):
    return np.sin(x)
X=np.linspace(0,10,10)
x=np.linspace(0,20,20)
y=x2(X)
Y=seno(X)
YY=np.concatenate((y,Y), axis=0)
YY=YY/max(YY)
#plt.plot(x,YY)
#plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
def Get_Dataset(n_b,b_idx,b_size):
    Size=n_b*b_idx
    print(Size)
    O=[];    Q=[];    A=[]
    for i in range(Size):
        a=rd.randint(0,200);        b=rd.randint(200,200+b_size)
        X=np.linspace(a,b,int(b_size/2));        x=np.linspace(a,b,b_size)
        y=x2(X);        y=y/max(y);        Y=seno(X)
#        print(y);        print(Y)
        YY=np.concatenate((y,Y), axis=0)
        O.append(YY)
        r=rd.randint(1,len(x)-1)
        Q.append(x[r]);        A.append(YY[r])

    
    O=torch.as_tensor(O)
    A=torch.as_tensor(A)
    Q=torch.as_tensor(Q)
    O=O.reshape(n_b,b_idx,b_size)
    Q=Q.reshape(n_b,b_idx,1)
    A=A.reshape(n_b,b_idx,1)
    print(np.shape(O));        print(np.shape(Q));        print(np.shape(A))
    return O,Q,A
        #plt.plot(x,YY)
        #plt.show()
        #s.exit()
O,Q,A=Get_Dataset(100,10,50)


n_batch=np.shape(O)[0]
batch_size=np.shape(O)[1]
n=np.shape(O)[2]
# Out:
# 1000
# torch.Size([100, 10, 50])
# torch.Size([100, 10, 1])
# torch.Size([100, 10, 1])
# /tmp/ipykernel_13027/823087914.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /opt/conda/conda-bld/pytorch_1639180507909/work/torch/csrc/utils/tensor_new.cpp:201.)
#   O=torch.as_tensor(O)

# %%
def Get_Dataset(n_b,b_idx,b_size):
    Size=n_b*b_idx
    O=[];    Q=[];    A=[]
    for i in range(Size):
        a=rd.randint(0,200);        b=rd.randint(200,200+b_size)
        X=np.linspace(a,b,int(b_size/2));        x=np.linspace(a,b,b_size)
        y=x2(X);        y=y/max(y);        Y=seno(X)
        YY=np.concatenate((y,Y), axis=0)
        O.append(YY)
        r=rd.randint(1,len(x)-1)
        Q.append(x[r]);        A.append(YY[r])
    O=torch.as_tensor(O)
    A=torch.as_tensor(A)
    Q=torch.as_tensor(Q)
    O=O.reshape(n_b,b_idx,b_size)
    Q=Q.reshape(n_b,b_idx,1)
    A=A.reshape(n_b,b_idx,1)
    print(np.shape(O));        print(np.shape(Q));        print(np.shape(A))
    address = open("positions","wb")
    pickle.dump(O, address)
    address.close()
    address = open("question","wb")
    pickle.dump(Q, address)
    address.close()
    address = open("answer","wb")
    pickle.dump(A, address)
    address.close()
    return O,Q,A
O,Q,A=Get_Dataset(20,100,50)
x=np.linspace(0,np.shape(O)[2],np.shape(O)[2])
y=O[0,0]
plt.plot(x,y)
plt.show()
# Out:
# torch.Size([20, 100, 50])
# torch.Size([20, 100, 1])
# torch.Size([20, 100, 1])

# %%
x=np.linspace(0,np.shape(O)[2],np.shape(O)[2])
y=O[0,10]
plt.plot(x,y)
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim

n_batch=np.shape(O)[0]
batch_size=np.shape(O)[1]
n=np.shape(O)[2]
print(n_batch)
print(batch_size)
print(n)
# Out:
# 20
# 100
# 50

# %%
#-------------------------------------------------------------------------------
#------------------DEFINE O MODELO----------------------------------------------
#-------------------------------------------------------------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        # N, 50
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(n,400),
            nn.Tanh(),
            nn.Linear(400,300),
            nn.Tanh(),
            nn.Linear(300,200),
            nn.Tanh(),
            nn.Linear(200,3),
            nn.Tanh(),
        )
        self.Decoder=nn.Sequential(
            nn.Linear(3,200),
            nn.Tanh(),
            nn.Linear(200,300),
            nn.Tanh(),
            nn.Linear(300,400),
            nn.Tanh(),
            nn.Linear(400,500),
            nn.Tanh(),
            nn.Linear(500,n),
        )
        self.project=nn.Linear(1,3)
        self.decoder=nn.Sequential(
            nn.Linear(6,100),
            nn.Tanh(),
            nn.Linear(100,200),
            nn.Tanh(),
            nn.Linear(200,450),
            nn.Tanh(),
            nn.Linear(450,50),
            nn.Tanh(),
            nn.Linear(50,1),
        )
    def forward(self, x, t,mode):
        if mode ==1:
            encoded = self.encoder(x)
            t=self.project(t)
            aux=torch.cat((encoded,t),1)
            decoded = self.decoder(aux)
        if mode == 2:
            encoded = self.encoder(x)
            decoded = self.Decoder(x)
        return decoded,encoded

# %%
model = Autoencoder()
for m in model.modules():
    if isinstance(m, (nn.Conv2d, nn.Linear)):
        nn.init.orthogonal_(m.weight)
criterion = nn.MSELoss() #segundo a investigar
optimizer = torch.optim.Adam(model.parameters())#,lr=1e-4,weight_decay = 1e-5)
#optimizer = torch.optim.SGD(model.parameters(),lr=1e-4,weight_decay = 1e-5)#,momentum=0.5)

# %%
def treine(epochs):
    O = pickle.load( open( "positions", "rb" ) )
    Q = pickle.load( open( "question", "rb" ) )
    A = pickle.load( open( "answer", "rb" ) )
    #print(np.shape(Q))
    #out =  pickle.load( open( "positions", "rb" ) )
    n_batch=np.shape(O)[0]
    batch_size=np.shape(O)[1]
    n_examples=np.shape(O)[2]
    #t=torch.as_tensor(np.zeros((batch_size,1)))
    #answ=torch.as_tensor(np.zeros((batch_size,1)))
    #indicedografico=0
    for epoch in range(epochs):
        for batch_idx in range(n_batch):
            o = O[batch_idx];            q = Q[batch_idx];            a = A[batch_idx]
            o = o.float();            q = q.float();            a = a.float()
            recon,latent = model(o,q,2)
            loss=torch.mean((recon-a)**2)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f'Epoch:{epoch+1},Loss:{loss.item():.4f}')
treine(90)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-fdc9b3376556> in <module>
#      21             optimizer.step()
#      22         print(f'Epoch:{epoch+1},Loss:{loss.item():.4f}')
# ---> 23 treine(90)
#
# <ipython-input-11-fdc9b3376556> in treine(epochs)
#      15             o = O[batch_idx];            q = Q[batch_idx];            a = A[batch_idx]
#      16             o = o.float();            q = q.float();            a = a.float()
# ---> 17             recon,latent = model(o,q,2)
#      18             loss=torch.mean((recon-a)**2)
#      19             optimizer.zero_grad()
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
# ...

# %%
# = pickle.load( open( "positions", "rb" ) )
# = pickle.load( open( "question", "rb" ) )
# = pickle.load( open( "answer", "rb" ) )
# = O[0]
# = Q[batch_idx]
# = o.float();q = q.float()
#econ,latent = model(o,q)


def Latent_values_Scynet2():
    fig = plt.figure(figsize=plt.figaspect(0.5))
    ax1 = fig.add_subplot(1, 3, 1, projection='3d')
    ax2 = fig.add_subplot(1, 3, 2, projection='3d')
    ax3 = fig.add_subplot(1, 3, 3, projection='3d')
    O = pickle.load( open( "positions", "rb" ) )
    Q = pickle.load( open( "question", "rb" ) )
    A = pickle.load( open( "answer", "rb" ) )
    #print(np.shape(Q))
    #out =  pickle.load( open( "positions", "rb" ) )
    n_batch=np.shape(O)[0]
    batch_size=np.shape(O)[1]
    n_examples=np.shape(O)[2]
    L1,L2,L3=np.zeros(batch_size),np.zeros(batch_size),np.zeros(batch_size)
    #t=torch.as_tensor(np.zeros((batch_size,1)))
    #answ=torch.as_tensor(np.zeros((batch_size,1)))
    #indicedografico=0
    epochs=1
    for epoch in range(epochs):
        for batch_idx in range(n_batch):
            rdn_batch=batch_idx
            o = O[batch_idx];            q = Q[batch_idx];            a = A[batch_idx]
            o = o.float();            q = q.float();            a = a.float()
            y,latent=model(o,q)
            print(latent)
            s.exit()
            #y=y.detach().numpy()[rdn_batch]
            #Y[interval]=y
            L1[rdn_batch] = latent[rdn_batch][0].detach().numpy()
            L2[rdn_batch] = latent[rdn_batch][1].detach().numpy()
            L3[rdn_batch] = latent[rdn_batch][2].detach().numpy()
            um   = latent[rdn_batch][0].detach().numpy()#.reshape(500)
            #um   = latent[rdn_batch][0].detach().numpy()#.reshape(500)
            dois = latent[rdn_batch][1].detach().numpy()#.reshape(500)
            #dois = latent[rdn_batch][1].detach().numpy()#.reshape(500)
            tres = latent[rdn_batch][2].detach().numpy()#.reshape(500)
            #tres = latent[rdn_batch][2].detach().numpy()#.reshape(500)
            um=np.array(um)
            dois=np.array(dois)
            tres=np.array(tres)
            k=np.array(K[aux][rdn_batch])
            b=np.array(B[aux][rdn_batch])
            #print(np.shape(B))
            #print(np.shape(K))
            #print(np.shape(L1))
            #print(um)
            #s.exit()
        surf=ax1.scatter3D(k, b, L1,label='Latent Activation 1' )
        surf=ax2.scatter3D(k, b, L2,label='Latent Activation 2' )
        surf=ax3.scatter3D(k, b, L3,label='Latent Activation 3' )
    plt.show()
Latent_values_Scynet2()
