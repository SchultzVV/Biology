# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import pickle
import sys as s
import random as rd
import torch
import torch.nn as nn
import torch.optim as optim
from pandas_ods_reader import read_ods
import sys as s

# %%
def Get_Dataset_real():  # Esse é o nome da função.
    y = []
    df = read_ods('data2.ods', headers=False)
    colunas = df.columns
    # print(colunas)
    Y = []
    for i in colunas:
        # for j in range(0,70):#df[i]:
        for j in df[i]:
            # print(df[i][j])
            if j != 0.0:
                y.append(j)
            # a+=1
            else:
                break
        Y.append(y)
        y = []
    print(np.shape(Y))

    address = open("Y_train", "wb")
    pickle.dump(Y, address)
    address.close()
    return Y


Y = Get_Dataset_real()
# Out:
# (45,)
# /home/v/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
index = rd.randint(0, np.shape(Y)[0])
y = 1*Y[index]
# y=1*Y[43]
print('o tamanho do gráfico é ',len(y))
x = np.linspace(0, len(y), len(y))
plt.plot(x, y)
plt.show()
# Out:
# /home/v/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape
# o tamanho do gráfico é  88

# %% [markdown]
# # 13/04/2022 parei aqui

# %% [markdown]
# ## Gera o dataset_1.0
#
# O dataset é composto de $$part_1=[y_1,..,y_{30}]$$ with dimension $d/2$ and $$label_1=[0].$$ For the initial part of the graph. Now for the second part of the graph we have $$part_2=[y_{d-30},...,y_d]$$ with dimension $d/2$ and with $$label_2=[1].$$

# %%
print(np.shape(Y))
for i in Y:
    print(len(i))
    break
# Out:
# (45,)
# 70
# /home/v/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
''' Gera o dataset
        O dataset é composto de $part_1=[y_0,..,y_{d/2}]$ with dimension $d/2$ and $label_1=[0]$ For the initial part of the graph.
        For the second part of the graph we have $part_2=[y_{d/2},...,y_d]$ with dimension $d/2$ and with $label_2=[1]$.
'''


def gen_dataset():
    Input = []
    Output = []
    Input_test = []
    Output_test = []
    j = 0
    for i in Y:
        if j < 10:
            y1 = i[0:30]
            Input.append(y1)
            Output.append(0)
            y2 = i[len(i)-30:len(i)]
            Input.append(y2)
            Output.append(1)
            j += 1
        else:
            y1 = i[0:30]
            Input_test.append(y1)
            Output_test.append(0)
            y2 = i[len(i)-30:len(i)]
            Input_test.append(y2)
            Output_test.append(1)
    # ---------------------- Salva o dataset com os 80 exemplos, ordenado em 4 grupos de 20
    print(np.shape(Input))
    print(np.shape(Output))
    print(np.shape(Input_test))
    print(np.shape(Output_test))
    # s.exit()
    Input = np.reshape(Input, (2, 10, 30))
    Output = np.reshape(Output, (2, 10, 1))
    Input = torch.as_tensor(Input)
    Output = torch.as_tensor(Output)
    address = open("Input_Train", "wb")
    pickle.dump(Input, address)
    address.close()
    address = open("Train_Labels", "wb")
    pickle.dump(Output, address)
    address.close()
    print("Input_Train", np.shape(Input))
    print("Train_Labels", np.shape(Output))

    # ---------------------- Salva o dataset com os 8 exemplos, ordenado em 4 grupos de 2
    Input_test = np.reshape(Input_test, (7, 10, 30))
    Output_test = np.reshape(Output_test, (7, 10, 1))
    Input_test = torch.as_tensor(Input_test)
    Output_test = torch.as_tensor(Output_test)
    address = open("Input_test", "wb")
    pickle.dump(Input_test, address)
    address.close()
    address = open("test_Labels", "wb")
    pickle.dump(Output_test, address)
    address.close()
    print("Input_test", np.shape(Input_test))
    print("test_Labels", np.shape(Output_test))
    return Input, Output, Input_test, Output_test


Input, Output, Input_test, Output_test = gen_dataset()
# Out:
# (20, 30)
# (20,)
# (70, 30)
# (70,)
# Input_Train torch.Size([2, 10, 30])
# Train_Labels torch.Size([2, 10, 1])
# Input_test torch.Size([7, 10, 30])
# test_Labels torch.Size([7, 10, 1])

# %%
n_examples = np.shape(Input)[2]
print(n_examples)
# Out:
# 30

# %%
# ------------------DEFINE O MODELO----------------------------------------------
# -------------------------------------------------------------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(n_examples, 720),
            nn.ReLU(),
            nn.Linear(720, 1500),
            nn.ReLU(),
            nn.Linear(1500, 2000),
            nn.ReLU(),
            nn.Linear(2000, 500),
            nn.ReLU(),
            nn.Linear(500, 50),
            nn.ReLU(),
            nn.Linear(50, 1),
            # nn.ELU()
            # nn.Softmax()
        )

    def forward(self, x):
        encoded = self.encoder(x)
#        print(np.shape(encoded))
#        print(np.shape(aux))
        #decoded = self.decoder(encoded)
        return encoded

# %%
# ------------------CHAMA O MODELO E INICIA CAMADAS DE PESOS ORTOGONAIS----------
# -------------------------------------------------------------------------------
model = Autoencoder()
for m in model.modules():
    if isinstance(m, (nn.Conv2d, nn.Linear)):
        nn.init.orthogonal_(m.weight)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)
# optimizer = torch.optim.SGD(model.parameters(),lr=1e-4,weight_decay = 1e-5)#,momentum=0.5)

# %%
import timeit


def treine(epochs):
    inp = pickle.load(open("Input_Train", "rb"))
    out = pickle.load(open("Train_Labels", "rb"))
    n_batch = np.shape(inp)[0]
    for epoch in range(epochs):
        for batch_idx in range(n_batch):
            O = inp[batch_idx]
            A = out[batch_idx]
            O = O.float()
            A = A.float()
            recon = model(O)
            loss = torch.mean((recon-A)**2)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f'Epoch:{epoch+1},Loss:{loss.item():.4f}')


start = timeit.default_timer()
treine(20)
end = timeit.default_timer()
print('tempo = ', end-start)
#'''1000 épocas leva 9 min approx'''
# Out:
# Epoch:1,Loss:0.4814
# Epoch:2,Loss:0.3584
# Epoch:3,Loss:0.2756
# Epoch:4,Loss:0.2338
# Epoch:5,Loss:0.2356
# Epoch:6,Loss:0.2482
# Epoch:7,Loss:0.2420
# Epoch:8,Loss:0.2308
# Epoch:9,Loss:0.2297
# Epoch:10,Loss:0.2353
# Epoch:11,Loss:0.2395
# Epoch:12,Loss:0.2379
# Epoch:13,Loss:0.2326
# Epoch:14,Loss:0.2277
# Epoch:15,Loss:0.2255
# Epoch:16,Loss:0.2251
# Epoch:17,Loss:0.2244
# Epoch:18,Loss:0.2233
# Epoch:19,Loss:0.2232
# Epoch:20,Loss:0.2240
# tempo =  1.3490749389984558

# %%
# -------------------------------------------------------------------------------
# ------TREINO DA IA-------------------------------------------------------------
# -------------------------------------------------------------------------------
def treine(epochs):
    inp = pickle.load(open("Input_Train", "rb"))
    out = pickle.load(open("Train_Labels", "rb"))
    n_batch = np.shape(inp)[0]
    for epoch in range(epochs):
        for batch_idx in range(n_batch):
            O = inp[batch_idx]
            A = out[batch_idx]
            O = O.float()
            A = A.float()
            recon = model(O)
            loss = torch.mean((recon-A)**2)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f'Epoch:{epoch+1},Loss:{loss.item():.4f}')


treine(1)
'''1000 épocas leva 9 min approx'''
# Out:
# Epoch:1,Loss:0.2243
# '1000 épocas leva 9 min approx'

# %%
PATH_save = 'new_data_state_model.pt'
torch.save(model.state_dict(), PATH_save)
# PATH_load='new_data_state_model.pt'
# model.load_state_dict(torch.load(PATH_load))

# %%
def random_predict():
    inp = pickle.load(open("Input_Train", "rb"))
    a = np.shape(inp)[0]-1
    b = np.shape(inp)[1]-1
    a_idx = rd.randint(0, a)
    b_idx = rd.randint(0, b)
    out = pickle.load(open("Train_Labels", "rb"))
    O = inp[a_idx]
    y = 1*O[b_idx]
    x = np.linspace(0, len(y), len(y))
    plt.plot(x, y)
    plt.show()
    A = out[a_idx]
    O = O.float()
    A = A.float()
    resposta = model(O)
    print('resposta = ', resposta[b_idx])
    print('label = ', A[b_idx])


random_predict()
# Out:
# resposta =  tensor([0.4236], grad_fn=<SelectBackward0>)
# label =  tensor([0.])

# %% [markdown]
# * Label = 0 (primeira parte do gráfico)
# * Label = 1 (segunda parte do gráfico)
# * Se a resposta for 0 quer dizer que a rede acha que o gráfico que foi apresentado é um gráfico do inicio.
# * Se a resposta for 1, a rede acha que é da segunda parte.

# %%
def predict_test():
    inp = pickle.load(open("Input_test", "rb"))
    a = np.shape(inp)[0]-1
    b = np.shape(inp)[1]-1
    a_idx = rd.randint(0, a)
    b_idx = rd.randint(0, b)
    out = pickle.load(open("test_Labels", "rb"))
    O = inp[a_idx]
    y = 1*O[b_idx]
    x = np.linspace(0, len(y), len(y))
    plt.plot(x, y)
    plt.show()
    A = out[a_idx]
    O = O.float()
    A = A.float()
    resposta = model(O)
    print('resposta = ', resposta[b_idx])
    print('label = ', A[b_idx])


predict_test()
# Out:
# resposta =  tensor([0.3489], grad_fn=<SelectBackward0>)
# label =  tensor([1.])

# %%
def Eval_metric(mode):
    if mode == 'test':
        inp = pickle.load(open("Input_test", "rb"))
        out = pickle.load(open("test_Labels", "rb"))
        size = np.shape(inp)[0]*np.shape(inp)[1]
        inp = inp.reshape(size, 30)
        out = out.reshape(size, 1)
    elif mode == 'treino':
        inp = pickle.load(open("Input_Train", "rb"))
        out = pickle.load(open("Train_Labels", "rb"))
        size = np.shape(inp)[0]*np.shape(inp)[1]
        inp = inp.reshape(size, 30)
        out = out.reshape(size, 1)
    O = inp.float()
    A = out.float()
    resposta = model(O)
    tolerance = 0.0001
    erro = 0
    acerto = 0
    for i in range(len(resposta)):
        if abs(resposta[i])-abs(A[i]) > tolerance:
            erro += 1
        else:
            acerto += 1
    print('erro = ', erro/size)
    print('acerto = ', acerto/size)
    return erro/size, acerto/size

# %%
Eval_metric('test')
# Out:
# erro =  0.5
# acerto =  0.5
# (0.5, 0.5)

# %%
Eval_metric('treino')
# Out:
# erro =  0.5
# acerto =  0.5
# (0.5, 0.5)

# %%
def gen_dataset(n_batch):
    Y = Get_Dataset_real()
    Input = []
    Output = []
    Input_test = []
    Output_test = []
    j = 0
    for i in Y:
        if j < n_batch*5:
            y1 = i[0:30]
            Input.append(y1)
            Output.append(0)
            y2 = i[len(i)-30:len(i)]
            Input.append(y2)
            Output.append(1)
            j += 1
        else:
            y1 = i[0:30]
            Input_test.append(y1)
            Output_test.append(0)
            y2 = i[len(i)-30:len(i)]
            Input_test.append(y2)
            Output_test.append(1)
    # ---------------------- Salva o dataset com os 80 exemplos, ordenado em 4 grupos de 20
    print(np.shape(Input))
    print(np.shape(Output))
    print(np.shape(Input_test))
    print(np.shape(Output_test))
    # s.exit()
    Input = np.reshape(Input, (n_batch, 10, 30))
    Output = np.reshape(Output, (n_batch, 10, 1))
    Input = torch.as_tensor(Input)
    Output = torch.as_tensor(Output)
    address = open("Input_Train", "wb")
    pickle.dump(Input, address)
    address.close()
    address = open("Train_Labels", "wb")
    pickle.dump(Output, address)
    address.close()
    print("Input_Train", np.shape(Input))
    print("Train_Labels", np.shape(Output))

    # ---------------------- Salva o dataset com os 8 exemplos, ordenado em 4 grupos de 2
    Input_test = np.reshape(Input_test, (abs(9-n_batch), 10, 30))
    Output_test = np.reshape(Output_test, (abs(9-n_batch), 10, 1))
    Input_test = torch.as_tensor(Input_test)
    Output_test = torch.as_tensor(Output_test)
    address = open("Input_test", "wb")
    pickle.dump(Input_test, address)
    address.close()
    address = open("test_Labels", "wb")
    pickle.dump(Output_test, address)
    address.close()
    print("Input_test", np.shape(Input_test))
    print("test_Labels", np.shape(Output_test))
    return Input, Output, Input_test, Output_test


Input, Output, Input_test, Output_test = gen_dataset(2)
# Out:
# (45,)
# (20, 30)
# (20,)
# (70, 30)
# (70,)
# Input_Train torch.Size([2, 10, 30])
# Train_Labels torch.Size([2, 10, 1])
# Input_test torch.Size([7, 10, 30])
# test_Labels torch.Size([7, 10, 1])
# /home/v/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
def reset_weight():
    model = Autoencoder()
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.orthogonal_(m.weight)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(
        model.parameters(), lr=1e-4, weight_decay=1e-5)

# %%
def eval_model(epochs):
    y1 = []
    y2 = []
    x = np.linspace(10, 90, 8)
    for i in range(1, 9):
        Input, Output, Input_test, Output_test = gen_dataset(i)
        reset_weight()
        treine(epochs)
        erro, acerto = Eval_metric('test')
        y1.append(erro)
        y2.append(acerto)
    plt.plot(x, y2)
    plt.xlabel('Exemplos de treino')
    plt.title('Acertos')
    plt.show()


eval_model(500)
# Out:
# (10, 30)
# (10,)
# (80, 30)
# (80,)
# Input_Train torch.Size([1, 10, 30])
# Train_Labels torch.Size([1, 10, 1])
# Input_test torch.Size([8, 10, 30])
# test_Labels torch.Size([8, 10, 1])
# Epoch:1,Loss:0.2245
# Epoch:2,Loss:0.2239
# Epoch:3,Loss:0.2232
# Epoch:4,Loss:0.2226
# Epoch:5,Loss:0.2219
# Epoch:6,Loss:0.2212
# Epoch:7,Loss:0.2204
# Epoch:8,Loss:0.2195
# Epoch:9,Loss:0.2186
# Epoch:10,Loss:0.2177
# Epoch:11,Loss:0.2167
# Epoch:12,Loss:0.2157
# Epoch:13,Loss:0.2147
# Epoch:14,Loss:0.2136
# Epoch:15,Loss:0.2124
# Epoch:16,Loss:0.2112
# Epoch:17,Loss:0.2099
# Epoch:18,Loss:0.2085
# Epoch:19,Loss:0.2071
# Epoch:20,Loss:0.2056
# Epoch:21,Loss:0.2040
# Epoch:22,Loss:0.2023
# Epoch:23,Loss:0.2006
# Epoch:24,Loss:0.1987
# Epoch:25,Loss:0.1968
# Epoch:26,Loss:0.1947
# Epoch:27,Loss:0.1926
# Epoch:28,Loss:0.1904
# Epoch:29,Loss:0.1880
# Epoch:30,Loss:0.1855
# Epoch:31,Loss:0.1829
# Epoch:32,Loss:0.1801
# Epoch:33,Loss:0.1772
# Epoch:34,Loss:0.1742
# Epoch:35,Loss:0.1710
# Epoch:36,Loss:0.1677
# Epoch:37,Loss:0.1642
# Epoch:38,Loss:0.1606
# Epoch:39,Loss:0.1569
# Epoch:40,Loss:0.1530
# Epoch:41,Loss:0.1489
# Epoch:42,Loss:0.1448
# Epoch:43,Loss:0.1406
# Epoch:44,Loss:0.1362
# Epoch:45,Loss:0.1317
# Epoch:46,Loss:0.1271
# Epoch:47,Loss:0.1226
# Epoch:48,Loss:0.1179
# Epoch:49,Loss:0.1132
# Epoch:50,Loss:0.1085
# Epoch:51,Loss:0.1040
# Epoch:52,Loss:0.0997
# Epoch:53,Loss:0.0955
# Epoch:54,Loss:0.0914
# Epoch:55,Loss:0.0875
# Epoch:56,Loss:0.0839
# Epoch:57,Loss:0.0806
# Epoch:58,Loss:0.0777
# Epoch:59,Loss:0.0750
# Epoch:60,Loss:0.0728
# Epoch:61,Loss:0.0708
# Epoch:62,Loss:0.0691
# Epoch:63,Loss:0.0675
# Epoch:64,Loss:0.0662
# Epoch:65,Loss:0.0651
# Epoch:66,Loss:0.0642
# Epoch:67,Loss:0.0632
# Epoch:68,Loss:0.0621
# Epoch:69,Loss:0.0614
# Epoch:70,Loss:0.0604
# Epoch:71,Loss:0.0595
# Epoch:72,Loss:0.0584
# Epoch:73,Loss:0.0573
# Epoch:74,Loss:0.0563
# Epoch:75,Loss:0.0552
# Epoch:76,Loss:0.0546
# Epoch:77,Loss:0.0549
# Epoch:78,Loss:0.0536
# Epoch:79,Loss:0.0513
# Epoch:80,Loss:0.0509
# Epoch:81,Loss:0.0502
# Epoch:82,Loss:0.0487
# Epoch:83,Loss:0.0478
# Epoch:84,Loss:0.0473
# Epoch:85,Loss:0.0460
# Epoch:86,Loss:0.0450
# Epoch:87,Loss:0.0443
# Epoch:88,Loss:0.0431
# Epoch:89,Loss:0.0421
# Epoch:90,Loss:0.0415
# Epoch:91,Loss:0.0409
# Epoch:92,Loss:0.0396
# Epoch:93,Loss:0.0384
# Epoch:94,Loss:0.0379
# Epoch:95,Loss:0.0371
# Epoch:96,Loss:0.0359
# Epoch:97,Loss:0.0348
# Epoch:98,Loss:0.0342
# Epoch:99,Loss:0.0335
# Epoch:100,Loss:0.0325
# Epoch:101,Loss:0.0314
# Epoch:102,Loss:0.0303
# Epoch:103,Loss:0.0295
# Epoch:104,Loss:0.0287
# Epoch:105,Loss:0.0279
# Epoch:106,Loss:0.0270
# Epoch:107,Loss:0.0262
# Epoch:108,Loss:0.0253
# Epoch:109,Loss:0.0246
# Epoch:110,Loss:0.0239
# Epoch:111,Loss:0.0234
# Epoch:112,Loss:0.0225
# Epoch:113,Loss:0.0212
# Epoch:114,Loss:0.0201
# Epoch:115,Loss:0.0196
# Epoch:116,Loss:0.0199
# Epoch:117,Loss:0.0198
# Epoch:118,Loss:0.0197
# Epoch:119,Loss:0.0173
# Epoch:120,Loss:0.0159
# Epoch:121,Loss:0.0160
# Epoch:122,Loss:0.0161
# Epoch:123,Loss:0.0160
# Epoch:124,Loss:0.0137
# Epoch:125,Loss:0.0131
# Epoch:126,Loss:0.0139
# Epoch:127,Loss:0.0134
# Epoch:128,Loss:0.0124
# Epoch:129,Loss:0.0110
# Epoch:130,Loss:0.0106
# Epoch:131,Loss:0.0114
# Epoch:132,Loss:0.0111
# Epoch:133,Loss:0.0096
# Epoch:134,Loss:0.0088
# Epoch:135,Loss:0.0087
# Epoch:136,Loss:0.0091
# Epoch:137,Loss:0.0090
# Epoch:138,Loss:0.0078
# Epoch:139,Loss:0.0072
# Epoch:140,Loss:0.0074
# Epoch:141,Loss:0.0073
# Epoch:142,Loss:0.0072
# Epoch:143,Loss:0.0063
# Epoch:144,Loss:0.0059
# Epoch:145,Loss:0.0061
# Epoch:146,Loss:0.0058
# Epoch:147,Loss:0.0052
# Epoch:148,Loss:0.0050
# Epoch:149,Loss:0.0051
# Epoch:150,Loss:0.0049
# Epoch:151,Loss:0.0044
# Epoch:152,Loss:0.0042
# Epoch:153,Loss:0.0042
# Epoch:154,Loss:0.0042
# Epoch:155,Loss:0.0041
# Epoch:156,Loss:0.0038
# Epoch:157,Loss:0.0035
# Epoch:158,Loss:0.0033
# Epoch:159,Loss:0.0032
# Epoch:160,Loss:0.0031
# Epoch:161,Loss:0.0029
# Epoch:162,Loss:0.0028
# Epoch:163,Loss:0.0027
# Epoch:164,Loss:0.0027
# Epoch:165,Loss:0.0026
# Epoch:166,Loss:0.0025
# Epoch:167,Loss:0.0023
# Epoch:168,Loss:0.0022
# Epoch:169,Loss:0.0021
# Epoch:170,Loss:0.0021
# Epoch:171,Loss:0.0020
# Epoch:172,Loss:0.0021
# Epoch:173,Loss:0.0021
# Epoch:174,Loss:0.0023
# Epoch:175,Loss:0.0024
# Epoch:176,Loss:0.0023
# Epoch:177,Loss:0.0019
# Epoch:178,Loss:0.0017
# Epoch:179,Loss:0.0017
# Epoch:180,Loss:0.0017
# Epoch:181,Loss:0.0016
# Epoch:182,Loss:0.0015
# Epoch:183,Loss:0.0015
# Epoch:184,Loss:0.0016
# Epoch:185,Loss:0.0015
# Epoch:186,Loss:0.0014
# Epoch:187,Loss:0.0013
# Epoch:188,Loss:0.0012
# Epoch:189,Loss:0.0012
# Epoch:190,Loss:0.0012
# Epoch:191,Loss:0.0012
# Epoch:192,Loss:0.0011
# Epoch:193,Loss:0.0011
# Epoch:194,Loss:0.0011
# Epoch:195,Loss:0.0011
# Epoch:196,Loss:0.0012
# Epoch:197,Loss:0.0012
# Epoch:198,Loss:0.0013
# Epoch:199,Loss:0.0012
# Epoch:200,Loss:0.0011
# Epoch:201,Loss:0.0009
# Epoch:202,Loss:0.0010
# Epoch:203,Loss:0.0009
# Epoch:204,Loss:0.0008
# Epoch:205,Loss:0.0009
# Epoch:206,Loss:0.0009
# Epoch:207,Loss:0.0010
# Epoch:208,Loss:0.0010
# Epoch:209,Loss:0.0010
# Epoch:210,Loss:0.0009
# Epoch:211,Loss:0.0007
# Epoch:212,Loss:0.0008
# Epoch:213,Loss:0.0008
# Epoch:214,Loss:0.0007
# Epoch:215,Loss:0.0007
# Epoch:216,Loss:0.0007
# Epoch:217,Loss:0.0006
# Epoch:218,Loss:0.0006
# Epoch:219,Loss:0.0006
# Epoch:220,Loss:0.0006
# Epoch:221,Loss:0.0006
# Epoch:222,Loss:0.0006
# Epoch:223,Loss:0.0005
# Epoch:224,Loss:0.0006
# Epoch:225,Loss:0.0006
# Epoch:226,Loss:0.0005
# Epoch:227,Loss:0.0005
# Epoch:228,Loss:0.0005
# Epoch:229,Loss:0.0005
# Epoch:230,Loss:0.0005
# Epoch:231,Loss:0.0005
# Epoch:232,Loss:0.0005
# Epoch:233,Loss:0.0005
# Epoch:234,Loss:0.0004
# Epoch:235,Loss:0.0004
# Epoch:236,Loss:0.0004
# Epoch:237,Loss:0.0004
# Epoch:238,Loss:0.0004
# Epoch:239,Loss:0.0004
# Epoch:240,Loss:0.0004
# Epoch:241,Loss:0.0004
# Epoch:242,Loss:0.0004
# Epoch:243,Loss:0.0003
# Epoch:244,Loss:0.0003
# Epoch:245,Loss:0.0003
# Epoch:246,Loss:0.0003
# Epoch:247,Loss:0.0003
# Epoch:248,Loss:0.0003
# Epoch:249,Loss:0.0003
# Epoch:250,Loss:0.0003
# Epoch:251,Loss:0.0003
# Epoch:252,Loss:0.0003
# Epoch:253,Loss:0.0003
# Epoch:254,Loss:0.0003
# Epoch:255,Loss:0.0003
# Epoch:256,Loss:0.0003
# Epoch:257,Loss:0.0003
# Epoch:258,Loss:0.0003
# Epoch:259,Loss:0.0003
# Epoch:260,Loss:0.0003
# Epoch:261,Loss:0.0003
# Epoch:262,Loss:0.0004
# Epoch:263,Loss:0.0006
# Epoch:264,Loss:0.0014
# Epoch:265,Loss:0.0037
# Epoch:266,Loss:0.0104
# Epoch:267,Loss:0.0380
# Epoch:268,Loss:0.0734
# Epoch:269,Loss:0.0084
# Epoch:270,Loss:0.0671
# Epoch:271,Loss:0.0065
# Epoch:272,Loss:0.0918
# Epoch:273,Loss:0.0066
# Epoch:274,Loss:0.0661
# Epoch:275,Loss:0.0260
# Epoch:276,Loss:0.0063
# Epoch:277,Loss:0.0462
# Epoch:278,Loss:0.0096
# Epoch:279,Loss:0.0095
# Epoch:280,Loss:0.0303
# Epoch:281,Loss:0.0130
# Epoch:282,Loss:0.0033
# Epoch:283,Loss:0.0190
# Epoch:284,Loss:0.0151
# Epoch:285,Loss:0.0024
# Epoch:286,Loss:0.0093
# Epoch:287,Loss:0.0143
# Epoch:288,Loss:0.0044
# Epoch:289,Loss:0.0031
# Epoch:290,Loss:0.0098
# Epoch:291,Loss:0.0071
# Epoch:292,Loss:0.0021
# Epoch:293,Loss:0.0045
# Epoch:294,Loss:0.0074
# Epoch:295,Loss:0.0041
# Epoch:296,Loss:0.0017
# Epoch:297,Loss:0.0039
# Epoch:298,Loss:0.0051
# Epoch:299,Loss:0.0025
# Epoch:300,Loss:0.0016
# Epoch:301,Loss:0.0033
# Epoch:302,Loss:0.0035
# Epoch:303,Loss:0.0017
# Epoch:304,Loss:0.0015
# Epoch:305,Loss:0.0026
# Epoch:306,Loss:0.0025
# Epoch:307,Loss:0.0013
# Epoch:308,Loss:0.0013
# Epoch:309,Loss:0.0020
# Epoch:310,Loss:0.0018
# Epoch:311,Loss:0.0011
# Epoch:312,Loss:0.0012
# Epoch:313,Loss:0.0016
# Epoch:314,Loss:0.0013
# Epoch:315,Loss:0.0009
# Epoch:316,Loss:0.0010
# Epoch:317,Loss:0.0012
# Epoch:318,Loss:0.0010
# Epoch:319,Loss:0.0008
# Epoch:320,Loss:0.0009
# Epoch:321,Loss:0.0010
# Epoch:322,Loss:0.0008
# Epoch:323,Loss:0.0007
# Epoch:324,Loss:0.0008
# Epoch:325,Loss:0.0008
# Epoch:326,Loss:0.0007
# Epoch:327,Loss:0.0006
# Epoch:328,Loss:0.0007
# Epoch:329,Loss:0.0007
# Epoch:330,Loss:0.0006
# Epoch:331,Loss:0.0006
# Epoch:332,Loss:0.0006
# Epoch:333,Loss:0.0006
# Epoch:334,Loss:0.0005
# Epoch:335,Loss:0.0005
# Epoch:336,Loss:0.0006
# Epoch:337,Loss:0.0005
# Epoch:338,Loss:0.0005
# Epoch:339,Loss:0.0005
# Epoch:340,Loss:0.0005
# Epoch:341,Loss:0.0005
# Epoch:342,Loss:0.0005
# Epoch:343,Loss:0.0005
# Epoch:344,Loss:0.0005
# Epoch:345,Loss:0.0004
# Epoch:346,Loss:0.0004
# Epoch:347,Loss:0.0004
# Epoch:348,Loss:0.0004
# Epoch:349,Loss:0.0004
# Epoch:350,Loss:0.0004
# Epoch:351,Loss:0.0004
# Epoch:352,Loss:0.0004
# Epoch:353,Loss:0.0004
# Epoch:354,Loss:0.0004
# Epoch:355,Loss:0.0004
# Epoch:356,Loss:0.0004
# Epoch:357,Loss:0.0003
# Epoch:358,Loss:0.0003
# Epoch:359,Loss:0.0003
# Epoch:360,Loss:0.0003
# Epoch:361,Loss:0.0003
# Epoch:362,Loss:0.0003
# Epoch:363,Loss:0.0003
# Epoch:364,Loss:0.0003
# Epoch:365,Loss:0.0003
# Epoch:366,Loss:0.0003
# Epoch:367,Loss:0.0003
# Epoch:368,Loss:0.0003
# Epoch:369,Loss:0.0003
# Epoch:370,Loss:0.0003
# Epoch:371,Loss:0.0003
# Epoch:372,Loss:0.0003
# Epoch:373,Loss:0.0002
# Epoch:374,Loss:0.0002
# Epoch:375,Loss:0.0002
# Epoch:376,Loss:0.0002
# Epoch:377,Loss:0.0002
# Epoch:378,Loss:0.0002
# Epoch:379,Loss:0.0002
# Epoch:380,Loss:0.0002
# Epoch:381,Loss:0.0002
# Epoch:382,Loss:0.0002
# Epoch:383,Loss:0.0002
# Epoch:384,Loss:0.0002
# Epoch:385,Loss:0.0002
# Epoch:386,Loss:0.0002
# Epoch:387,Loss:0.0002
# Epoch:388,Loss:0.0002
# Epoch:389,Loss:0.0002
# Epoch:390,Loss:0.0002
# Epoch:391,Loss:0.0002
# Epoch:392,Loss:0.0002
# Epoch:393,Loss:0.0001
# Epoch:394,Loss:0.0001
# Epoch:395,Loss:0.0001
# Epoch:396,Loss:0.0001
# Epoch:397,Loss:0.0001
# Epoch:398,Loss:0.0001
# Epoch:399,Loss:0.0001
# Epoch:400,Loss:0.0001
# Epoch:401,Loss:0.0001
# Epoch:402,Loss:0.0001
# Epoch:403,Loss:0.0001
# Epoch:404,Loss:0.0001
# Epoch:405,Loss:0.0001
# Epoch:406,Loss:0.0001
# Epoch:407,Loss:0.0001
# Epoch:408,Loss:0.0001
# Epoch:409,Loss:0.0001
# Epoch:410,Loss:0.0001
# Epoch:411,Loss:0.0001
# Epoch:412,Loss:0.0001
# Epoch:413,Loss:0.0001
# Epoch:414,Loss:0.0001
# Epoch:415,Loss:0.0001
# Epoch:416,Loss:0.0001
# Epoch:417,Loss:0.0001
# Epoch:418,Loss:0.0001
# Epoch:419,Loss:0.0001
# Epoch:420,Loss:0.0001
# Epoch:421,Loss:0.0001
# Epoch:422,Loss:0.0001
# Epoch:423,Loss:0.0001
# Epoch:424,Loss:0.0001
# Epoch:425,Loss:0.0001
# Epoch:426,Loss:0.0001
# Epoch:427,Loss:0.0001
# Epoch:428,Loss:0.0001
# Epoch:429,Loss:0.0001
# Epoch:430,Loss:0.0000
# Epoch:431,Loss:0.0000
# Epoch:432,Loss:0.0000
# Epoch:433,Loss:0.0000
# Epoch:434,Loss:0.0000
# Epoch:435,Loss:0.0000
# Epoch:436,Loss:0.0000
# Epoch:437,Loss:0.0000
# Epoch:438,Loss:0.0000
# Epoch:439,Loss:0.0000
# Epoch:440,Loss:0.0000
# Epoch:441,Loss:0.0000
# Epoch:442,Loss:0.0000
# Epoch:443,Loss:0.0000
# Epoch:444,Loss:0.0000
# Epoch:445,Loss:0.0000
# Epoch:446,Loss:0.0000
# Epoch:447,Loss:0.0000
# Epoch:448,Loss:0.0000
# Epoch:449,Loss:0.0000
# Epoch:450,Loss:0.0000
# Epoch:451,Loss:0.0000
# Epoch:452,Loss:0.0000
# Epoch:453,Loss:0.0000
# Epoch:454,Loss:0.0000
# Epoch:455,Loss:0.0000
# Epoch:456,Loss:0.0000
# Epoch:457,Loss:0.0000
# Epoch:458,Loss:0.0000
# Epoch:459,Loss:0.0000
# Epoch:460,Loss:0.0000
# Epoch:461,Loss:0.0000
# Epoch:462,Loss:0.0000
# Epoch:463,Loss:0.0000
# Epoch:464,Loss:0.0000
# Epoch:465,Loss:0.0000
# Epoch:466,Loss:0.0000
# Epoch:467,Loss:0.0000
# Epoch:468,Loss:0.0000
# Epoch:469,Loss:0.0000
# Epoch:470,Loss:0.0000
# Epoch:471,Loss:0.0000
# Epoch:472,Loss:0.0000
# Epoch:473,Loss:0.0000
# Epoch:474,Loss:0.0000
# Epoch:475,Loss:0.0000
# Epoch:476,Loss:0.0000
# Epoch:477,Loss:0.0000
# Epoch:478,Loss:0.0000
# Epoch:479,Loss:0.0000
# Epoch:480,Loss:0.0000
# Epoch:481,Loss:0.0000
# Epoch:482,Loss:0.0000
# Epoch:483,Loss:0.0000
# Epoch:484,Loss:0.0000
# Epoch:485,Loss:0.0000
# Epoch:486,Loss:0.0000
# Epoch:487,Loss:0.0000
# Epoch:488,Loss:0.0000
# Epoch:489,Loss:0.0000
# Epoch:490,Loss:0.0000
# Epoch:491,Loss:0.0000
# Epoch:492,Loss:0.0000
# Epoch:493,Loss:0.0000
# Epoch:494,Loss:0.0000
# Epoch:495,Loss:0.0000
# Epoch:496,Loss:0.0000
# Epoch:497,Loss:0.0000
# Epoch:498,Loss:0.0000
# Epoch:499,Loss:0.0000
# Epoch:500,Loss:0.0000
# erro =  0.55
# acerto =  0.45
# (20, 30)
# (20,)
# (70, 30)
# (70,)
# Input_Train torch.Size([2, 10, 30])
# Train_Labels torch.Size([2, 10, 1])
# Input_test torch.Size([7, 10, 30])
# test_Labels torch.Size([7, 10, 1])
# Epoch:1,Loss:0.2680
# Epoch:2,Loss:0.2367
# Epoch:3,Loss:0.2609
# Epoch:4,Loss:0.2444
# Epoch:5,Loss:0.3892
# Epoch:6,Loss:0.2251
# Epoch:7,Loss:0.1777
# Epoch:8,Loss:0.2765
# Epoch:9,Loss:0.1702
# Epoch:10,Loss:0.1678
# Epoch:11,Loss:0.2261
# Epoch:12,Loss:0.1548
# Epoch:13,Loss:0.1599
# Epoch:14,Loss:0.2151
# Epoch:15,Loss:0.1433
# Epoch:16,Loss:0.1431
# Epoch:17,Loss:0.2015
# Epoch:18,Loss:0.1299
# Epoch:19,Loss:0.1246
# Epoch:20,Loss:0.1632
# Epoch:21,Loss:0.1258
# Epoch:22,Loss:0.1359
# Epoch:23,Loss:0.1092
# Epoch:24,Loss:0.1049
# Epoch:25,Loss:0.1233
# Epoch:26,Loss:0.1018
# Epoch:27,Loss:0.1324
# Epoch:28,Loss:0.0960
# Epoch:29,Loss:0.1180
# Epoch:30,Loss:0.0877
# Epoch:31,Loss:0.0995
# Epoch:32,Loss:0.0814
# Epoch:33,Loss:0.0900
# Epoch:34,Loss:0.0769
# Epoch:35,Loss:0.0991
# Epoch:36,Loss:0.0830
# Epoch:37,Loss:0.1292
# Epoch:38,Loss:0.0885
# Epoch:39,Loss:0.1154
# Epoch:40,Loss:0.0695
# Epoch:41,Loss:0.0770
# Epoch:42,Loss:0.0610
# Epoch:43,Loss:0.0634
# Epoch:44,Loss:0.0583
# Epoch:45,Loss:0.0608
# Epoch:46,Loss:0.0552
# Epoch:47,Loss:0.0719
# Epoch:48,Loss:0.0612
# Epoch:49,Loss:0.0984
# Epoch:50,Loss:0.0686
# Epoch:51,Loss:0.0959
# Epoch:52,Loss:0.0562
# Epoch:53,Loss:0.0571
# Epoch:54,Loss:0.0481
# Epoch:55,Loss:0.0427
# Epoch:56,Loss:0.0584
# Epoch:57,Loss:0.0417
# Epoch:58,Loss:0.0583
# Epoch:59,Loss:0.0384
# Epoch:60,Loss:0.0464
# Epoch:61,Loss:0.0374
# Epoch:62,Loss:0.0349
# Epoch:63,Loss:0.0403
# Epoch:64,Loss:0.0319
# Epoch:65,Loss:0.0334
# Epoch:66,Loss:0.0342
# Epoch:67,Loss:0.0288
# Epoch:68,Loss:0.0344
# Epoch:69,Loss:0.0276
# Epoch:70,Loss:0.0292
# Epoch:71,Loss:0.0293
# Epoch:72,Loss:0.0249
# Epoch:73,Loss:0.0271
# Epoch:74,Loss:0.0256
# Epoch:75,Loss:0.0234
# Epoch:76,Loss:0.0251
# Epoch:77,Loss:0.0219
# Epoch:78,Loss:0.0224
# Epoch:79,Loss:0.0217
# Epoch:80,Loss:0.0200
# Epoch:81,Loss:0.0208
# Epoch:82,Loss:0.0191
# Epoch:83,Loss:0.0192
# Epoch:84,Loss:0.0184
# Epoch:85,Loss:0.0170
# Epoch:86,Loss:0.0173
# Epoch:87,Loss:0.0161
# Epoch:88,Loss:0.0160
# Epoch:89,Loss:0.0148
# Epoch:90,Loss:0.0146
# Epoch:91,Loss:0.0139
# Epoch:92,Loss:0.0134
# Epoch:93,Loss:0.0130
# Epoch:94,Loss:0.0124
# Epoch:95,Loss:0.0124
# Epoch:96,Loss:0.0115
# Epoch:97,Loss:0.0116
# Epoch:98,Loss:0.0106
# Epoch:99,Loss:0.0105
# Epoch:100,Loss:0.0099
# Epoch:101,Loss:0.0096
# Epoch:102,Loss:0.0091
# Epoch:103,Loss:0.0089
# Epoch:104,Loss:0.0086
# Epoch:105,Loss:0.0082
# Epoch:106,Loss:0.0077
# Epoch:107,Loss:0.0075
# Epoch:108,Loss:0.0073
# Epoch:109,Loss:0.0067
# Epoch:110,Loss:0.0066
# Epoch:111,Loss:0.0063
# Epoch:112,Loss:0.0060
# Epoch:113,Loss:0.0057
# Epoch:114,Loss:0.0054
# Epoch:115,Loss:0.0052
# Epoch:116,Loss:0.0049
# Epoch:117,Loss:0.0047
# Epoch:118,Loss:0.0046
# Epoch:119,Loss:0.0043
# Epoch:120,Loss:0.0042
# Epoch:121,Loss:0.0041
# Epoch:122,Loss:0.0039
# Epoch:123,Loss:0.0041
# Epoch:124,Loss:0.0038
# Epoch:125,Loss:0.0075
# Epoch:126,Loss:0.0064
# Epoch:127,Loss:0.0127
# Epoch:128,Loss:0.0086
# Epoch:129,Loss:0.0144
# Epoch:130,Loss:0.0058
# Epoch:131,Loss:0.0099
# Epoch:132,Loss:0.0044
# Epoch:133,Loss:0.0035
# Epoch:134,Loss:0.0102
# Epoch:135,Loss:0.0085
# Epoch:136,Loss:0.0104
# Epoch:137,Loss:0.0036
# Epoch:138,Loss:0.0033
# Epoch:139,Loss:0.0047
# Epoch:140,Loss:0.0033
# Epoch:141,Loss:0.0036
# Epoch:142,Loss:0.0023
# Epoch:143,Loss:0.0021
# Epoch:144,Loss:0.0023
# Epoch:145,Loss:0.0018
# Epoch:146,Loss:0.0018
# Epoch:147,Loss:0.0021
# Epoch:148,Loss:0.0018
# Epoch:149,Loss:0.0019
# Epoch:150,Loss:0.0013
# Epoch:151,Loss:0.0014
# Epoch:152,Loss:0.0015
# Epoch:153,Loss:0.0013
# Epoch:154,Loss:0.0014
# Epoch:155,Loss:0.0013
# Epoch:156,Loss:0.0012
# Epoch:157,Loss:0.0013
# Epoch:158,Loss:0.0011
# Epoch:159,Loss:0.0011
# Epoch:160,Loss:0.0010
# Epoch:161,Loss:0.0009
# Epoch:162,Loss:0.0010
# Epoch:163,Loss:0.0009
# Epoch:164,Loss:0.0012
# Epoch:165,Loss:0.0010
# Epoch:166,Loss:0.0011
# Epoch:167,Loss:0.0008
# Epoch:168,Loss:0.0009
# Epoch:169,Loss:0.0007
# Epoch:170,Loss:0.0007
# Epoch:171,Loss:0.0007
# Epoch:172,Loss:0.0007
# Epoch:173,Loss:0.0008
# Epoch:174,Loss:0.0008
# Epoch:175,Loss:0.0011
# Epoch:176,Loss:0.0008
# Epoch:177,Loss:0.0009
# Epoch:178,Loss:0.0006
# Epoch:179,Loss:0.0006
# Epoch:180,Loss:0.0007
# Epoch:181,Loss:0.0007
# Epoch:182,Loss:0.0009
# Epoch:183,Loss:0.0008
# Epoch:184,Loss:0.0009
# Epoch:185,Loss:0.0006
# Epoch:186,Loss:0.0006
# Epoch:187,Loss:0.0005
# Epoch:188,Loss:0.0005
# Epoch:189,Loss:0.0005
# Epoch:190,Loss:0.0005
# Epoch:191,Loss:0.0005
# Epoch:192,Loss:0.0005
# Epoch:193,Loss:0.0005
# Epoch:194,Loss:0.0005
# Epoch:195,Loss:0.0005
# Epoch:196,Loss:0.0006
# Epoch:197,Loss:0.0007
# Epoch:198,Loss:0.0006
# Epoch:199,Loss:0.0006
# Epoch:200,Loss:0.0004
# Epoch:201,Loss:0.0004
# Epoch:202,Loss:0.0005
# Epoch:203,Loss:0.0005
# Epoch:204,Loss:0.0006
# Epoch:205,Loss:0.0004
# Epoch:206,Loss:0.0004
# Epoch:207,Loss:0.0005
# Epoch:208,Loss:0.0005
# Epoch:209,Loss:0.0006
# Epoch:210,Loss:0.0004
# Epoch:211,Loss:0.0004
# Epoch:212,Loss:0.0005
# Epoch:213,Loss:0.0005
# Epoch:214,Loss:0.0005
# Epoch:215,Loss:0.0004
# Epoch:216,Loss:0.0003
# Epoch:217,Loss:0.0004
# Epoch:218,Loss:0.0004
# Epoch:219,Loss:0.0003
# Epoch:220,Loss:0.0004
# Epoch:221,Loss:0.0004
# Epoch:222,Loss:0.0003
# Epoch:223,Loss:0.0003
# Epoch:224,Loss:0.0003
# Epoch:225,Loss:0.0003
# Epoch:226,Loss:0.0003
# Epoch:227,Loss:0.0003
# Epoch:228,Loss:0.0003
# Epoch:229,Loss:0.0003
# Epoch:230,Loss:0.0004
# Epoch:231,Loss:0.0004
# Epoch:232,Loss:0.0003
# Epoch:233,Loss:0.0003
# Epoch:234,Loss:0.0003
# Epoch:235,Loss:0.0003
# Epoch:236,Loss:0.0002
# Epoch:237,Loss:0.0003
# Epoch:238,Loss:0.0002
# Epoch:239,Loss:0.0002
# Epoch:240,Loss:0.0003
# Epoch:241,Loss:0.0003
# Epoch:242,Loss:0.0003
# Epoch:243,Loss:0.0002
# Epoch:244,Loss:0.0003
# Epoch:245,Loss:0.0002
# Epoch:246,Loss:0.0002
# Epoch:247,Loss:0.0002
# Epoch:248,Loss:0.0002
# Epoch:249,Loss:0.0003
# Epoch:250,Loss:0.0003
# Epoch:251,Loss:0.0002
# Epoch:252,Loss:0.0003
# Epoch:253,Loss:0.0003
# Epoch:254,Loss:0.0004
# Epoch:255,Loss:0.0002
# Epoch:256,Loss:0.0002
# Epoch:257,Loss:0.0003
# Epoch:258,Loss:0.0002
# Epoch:259,Loss:0.0002
# Epoch:260,Loss:0.0002
# Epoch:261,Loss:0.0002
# Epoch:262,Loss:0.0002
# Epoch:263,Loss:0.0002
# Epoch:264,Loss:0.0002
# Epoch:265,Loss:0.0002
# Epoch:266,Loss:0.0002
# Epoch:267,Loss:0.0002
# Epoch:268,Loss:0.0001
# Epoch:269,Loss:0.0002
# Epoch:270,Loss:0.0001
# Epoch:271,Loss:0.0001
# Epoch:272,Loss:0.0001
# Epoch:273,Loss:0.0001
# Epoch:274,Loss:0.0001
# Epoch:275,Loss:0.0001
# Epoch:276,Loss:0.0001
# Epoch:277,Loss:0.0001
# Epoch:278,Loss:0.0001
# Epoch:279,Loss:0.0001
# Epoch:280,Loss:0.0001
# Epoch:281,Loss:0.0001
# Epoch:282,Loss:0.0001
# Epoch:283,Loss:0.0001
# Epoch:284,Loss:0.0001
# Epoch:285,Loss:0.0001
# Epoch:286,Loss:0.0001
# Epoch:287,Loss:0.0001
# Epoch:288,Loss:0.0001
# Epoch:289,Loss:0.0001
# Epoch:290,Loss:0.0001
# Epoch:291,Loss:0.0001
# Epoch:292,Loss:0.0001
# Epoch:293,Loss:0.0001
# Epoch:294,Loss:0.0001
# Epoch:295,Loss:0.0001
# Epoch:296,Loss:0.0001
# Epoch:297,Loss:0.0001
# Epoch:298,Loss:0.0001
# Epoch:299,Loss:0.0001
# Epoch:300,Loss:0.0001
# Epoch:301,Loss:0.0001
# Epoch:302,Loss:0.0001
# Epoch:303,Loss:0.0001
# Epoch:304,Loss:0.0001
# Epoch:305,Loss:0.0001
# Epoch:306,Loss:0.0001
# Epoch:307,Loss:0.0001
# Epoch:308,Loss:0.0001
# Epoch:309,Loss:0.0001
# Epoch:310,Loss:0.0001
# Epoch:311,Loss:0.0001
# Epoch:312,Loss:0.0001
# Epoch:313,Loss:0.0001
# Epoch:314,Loss:0.0001
# Epoch:315,Loss:0.0001
# Epoch:316,Loss:0.0001
# Epoch:317,Loss:0.0001
# Epoch:318,Loss:0.0001
# Epoch:319,Loss:0.0001
# Epoch:320,Loss:0.0001
# Epoch:321,Loss:0.0001
# Epoch:322,Loss:0.0001
# Epoch:323,Loss:0.0001
# Epoch:324,Loss:0.0001
# Epoch:325,Loss:0.0001
# Epoch:326,Loss:0.0001
# Epoch:327,Loss:0.0001
# Epoch:328,Loss:0.0001
# Epoch:329,Loss:0.0001
# Epoch:330,Loss:0.0001
# Epoch:331,Loss:0.0001
# Epoch:332,Loss:0.0001
# Epoch:333,Loss:0.0001
# Epoch:334,Loss:0.0001
# Epoch:335,Loss:0.0001
# Epoch:336,Loss:0.0001
# Epoch:337,Loss:0.0001
# Epoch:338,Loss:0.0001
# Epoch:339,Loss:0.0000
# Epoch:340,Loss:0.0000
# Epoch:341,Loss:0.0001
# Epoch:342,Loss:0.0001
# Epoch:343,Loss:0.0001
# Epoch:344,Loss:0.0000
# Epoch:345,Loss:0.0000
# Epoch:346,Loss:0.0001
# Epoch:347,Loss:0.0001
# Epoch:348,Loss:0.0001
# Epoch:349,Loss:0.0000
# Epoch:350,Loss:0.0001
# Epoch:351,Loss:0.0001
# Epoch:352,Loss:0.0000
# Epoch:353,Loss:0.0000
# Epoch:354,Loss:0.0001
# Epoch:355,Loss:0.0001
# Epoch:356,Loss:0.0001
# Epoch:357,Loss:0.0000
# Epoch:358,Loss:0.0000
# Epoch:359,Loss:0.0001
# Epoch:360,Loss:0.0001
# Epoch:361,Loss:0.0001
# Epoch:362,Loss:0.0000
# Epoch:363,Loss:0.0001
# Epoch:364,Loss:0.0000
# Epoch:365,Loss:0.0000
# Epoch:366,Loss:0.0000
# Epoch:367,Loss:0.0000
# Epoch:368,Loss:0.0000
# Epoch:369,Loss:0.0000
# Epoch:370,Loss:0.0000
# Epoch:371,Loss:0.0000
# Epoch:372,Loss:0.0000
# Epoch:373,Loss:0.0000
# Epoch:374,Loss:0.0000
# Epoch:375,Loss:0.0000
# Epoch:376,Loss:0.0000
# Epoch:377,Loss:0.0000
# Epoch:378,Loss:0.0000
# Epoch:379,Loss:0.0000
# Epoch:380,Loss:0.0000
# Epoch:381,Loss:0.0000
# Epoch:382,Loss:0.0000
# Epoch:383,Loss:0.0000
# Epoch:384,Loss:0.0000
# Epoch:385,Loss:0.0000
# Epoch:386,Loss:0.0000
# Epoch:387,Loss:0.0000
# Epoch:388,Loss:0.0000
# Epoch:389,Loss:0.0000
# Epoch:390,Loss:0.0000
# Epoch:391,Loss:0.0000
# Epoch:392,Loss:0.0000
# Epoch:393,Loss:0.0000
# Epoch:394,Loss:0.0000
# Epoch:395,Loss:0.0000
# Epoch:396,Loss:0.0000
# Epoch:397,Loss:0.0000
# Epoch:398,Loss:0.0000
# Epoch:399,Loss:0.0000
# Epoch:400,Loss:0.0000
# Epoch:401,Loss:0.0000
# Epoch:402,Loss:0.0000
# Epoch:403,Loss:0.0000
# Epoch:404,Loss:0.0000
# Epoch:405,Loss:0.0000
# Epoch:406,Loss:0.0000
# Epoch:407,Loss:0.0000
# Epoch:408,Loss:0.0001
# Epoch:409,Loss:0.0001
# Epoch:410,Loss:0.0000
# Epoch:411,Loss:0.0000
# Epoch:412,Loss:0.0001
# Epoch:413,Loss:0.0001
# Epoch:414,Loss:0.0000
# Epoch:415,Loss:0.0000
# Epoch:416,Loss:0.0000
# Epoch:417,Loss:0.0000
# Epoch:418,Loss:0.0000
# Epoch:419,Loss:0.0000
# Epoch:420,Loss:0.0000
# Epoch:421,Loss:0.0000
# Epoch:422,Loss:0.0000
# Epoch:423,Loss:0.0000
# Epoch:424,Loss:0.0000
# Epoch:425,Loss:0.0000
# Epoch:426,Loss:0.0000
# Epoch:427,Loss:0.0000
# Epoch:428,Loss:0.0000
# Epoch:429,Loss:0.0000
# Epoch:430,Loss:0.0000
# Epoch:431,Loss:0.0000
# Epoch:432,Loss:0.0000
# Epoch:433,Loss:0.0000
# Epoch:434,Loss:0.0000
# Epoch:435,Loss:0.0000
# Epoch:436,Loss:0.0000
# Epoch:437,Loss:0.0000
# Epoch:438,Loss:0.0000
# Epoch:439,Loss:0.0000
# Epoch:440,Loss:0.0000
# Epoch:441,Loss:0.0000
# Epoch:442,Loss:0.0000
# Epoch:443,Loss:0.0000
# Epoch:444,Loss:0.0000
# Epoch:445,Loss:0.0000
# Epoch:446,Loss:0.0000
# Epoch:447,Loss:0.0000
# Epoch:448,Loss:0.0000
# Epoch:449,Loss:0.0000
# Epoch:450,Loss:0.0000
# Epoch:451,Loss:0.0000
# Epoch:452,Loss:0.0000
# Epoch:453,Loss:0.0000
# Epoch:454,Loss:0.0000
# Epoch:455,Loss:0.0000
# Epoch:456,Loss:0.0000
# Epoch:457,Loss:0.0000
# Epoch:458,Loss:0.0000
# Epoch:459,Loss:0.0000
# Epoch:460,Loss:0.0000
# Epoch:461,Loss:0.0000
# Epoch:462,Loss:0.0000
# Epoch:463,Loss:0.0000
# Epoch:464,Loss:0.0000
# Epoch:465,Loss:0.0000
# Epoch:466,Loss:0.0000
# Epoch:467,Loss:0.0000
# Epoch:468,Loss:0.0000
# Epoch:469,Loss:0.0000
# Epoch:470,Loss:0.0000
# Epoch:471,Loss:0.0000
# Epoch:472,Loss:0.0000
# Epoch:473,Loss:0.0000
# Epoch:474,Loss:0.0000
# Epoch:475,Loss:0.0000
# Epoch:476,Loss:0.0000
# Epoch:477,Loss:0.0000
# Epoch:478,Loss:0.0000
# Epoch:479,Loss:0.0000
# Epoch:480,Loss:0.0000
# Epoch:481,Loss:0.0000
# Epoch:482,Loss:0.0000
# Epoch:483,Loss:0.0000
# Epoch:484,Loss:0.0000
# Epoch:485,Loss:0.0000
# Epoch:486,Loss:0.0000
# Epoch:487,Loss:0.0000
# Epoch:488,Loss:0.0000
# Epoch:489,Loss:0.0000
# Epoch:490,Loss:0.0000
# Epoch:491,Loss:0.0000
# Epoch:492,Loss:0.0000
# Epoch:493,Loss:0.0000
# Epoch:494,Loss:0.0000
# Epoch:495,Loss:0.0000
# Epoch:496,Loss:0.0000
# Epoch:497,Loss:0.0000
# Epoch:498,Loss:0.0000
# Epoch:499,Loss:0.0000
# Epoch:500,Loss:0.0000
# erro =  0.6714285714285714
# acerto =  0.32857142857142857
# (30, 30)
# (30,)
# (60, 30)
# (60,)
# Input_Train torch.Size([3, 10, 30])
# Train_Labels torch.Size([3, 10, 1])
# Input_test torch.Size([6, 10, 30])
# test_Labels torch.Size([6, 10, 1])
# Epoch:1,Loss:0.1154
# Epoch:2,Loss:0.0705
# Epoch:3,Loss:0.1253
# Epoch:4,Loss:0.1426
# Epoch:5,Loss:0.1070
# Epoch:6,Loss:0.0866
# Epoch:7,Loss:0.1304
# Epoch:8,Loss:0.0846
# Epoch:9,Loss:0.0654
# Epoch:10,Loss:0.0767
# Epoch:11,Loss:0.0883
# Epoch:12,Loss:0.0522
# Epoch:13,Loss:0.1246
# Epoch:14,Loss:0.0281
# Epoch:15,Loss:0.0310
# Epoch:16,Loss:0.0981
# Epoch:17,Loss:0.0402
# Epoch:18,Loss:0.0505
# Epoch:19,Loss:0.1008
# Epoch:20,Loss:0.0390
# Epoch:21,Loss:0.0272
# Epoch:22,Loss:0.0410
# Epoch:23,Loss:0.0262
# Epoch:24,Loss:0.0333
# Epoch:25,Loss:0.0280
# Epoch:26,Loss:0.0239
# Epoch:27,Loss:0.0235
# Epoch:28,Loss:0.0175
# Epoch:29,Loss:0.0183
# Epoch:30,Loss:0.0149
# Epoch:31,Loss:0.0160
# Epoch:32,Loss:0.0432
# Epoch:33,Loss:0.0115
# Epoch:34,Loss:0.0440
# Epoch:35,Loss:0.0122
# Epoch:36,Loss:0.0217
# Epoch:37,Loss:0.0133
# Epoch:38,Loss:0.0107
# Epoch:39,Loss:0.0214
# Epoch:40,Loss:0.0103
# Epoch:41,Loss:0.0112
# Epoch:42,Loss:0.0084
# Epoch:43,Loss:0.0086
# Epoch:44,Loss:0.0085
# Epoch:45,Loss:0.0069
# Epoch:46,Loss:0.0072
# Epoch:47,Loss:0.0066
# Epoch:48,Loss:0.0065
# Epoch:49,Loss:0.0062
# Epoch:50,Loss:0.0059
# Epoch:51,Loss:0.0058
# Epoch:52,Loss:0.0054
# Epoch:53,Loss:0.0053
# Epoch:54,Loss:0.0051
# Epoch:55,Loss:0.0049
# Epoch:56,Loss:0.0047
# Epoch:57,Loss:0.0044
# Epoch:58,Loss:0.0041
# Epoch:59,Loss:0.0039
# Epoch:60,Loss:0.0038
# Epoch:61,Loss:0.0038
# Epoch:62,Loss:0.0037
# Epoch:63,Loss:0.0037
# Epoch:64,Loss:0.0035
# Epoch:65,Loss:0.0033
# Epoch:66,Loss:0.0032
# Epoch:67,Loss:0.0030
# Epoch:68,Loss:0.0030
# Epoch:69,Loss:0.0030
# Epoch:70,Loss:0.0029
# Epoch:71,Loss:0.0028
# Epoch:72,Loss:0.0028
# Epoch:73,Loss:0.0026
# Epoch:74,Loss:0.0025
# Epoch:75,Loss:0.0024
# Epoch:76,Loss:0.0024
# Epoch:77,Loss:0.0023
# Epoch:78,Loss:0.0022
# Epoch:79,Loss:0.0022
# Epoch:80,Loss:0.0021
# Epoch:81,Loss:0.0020
# Epoch:82,Loss:0.0020
# Epoch:83,Loss:0.0019
# Epoch:84,Loss:0.0018
# Epoch:85,Loss:0.0018
# Epoch:86,Loss:0.0017
# Epoch:87,Loss:0.0017
# Epoch:88,Loss:0.0016
# Epoch:89,Loss:0.0016
# Epoch:90,Loss:0.0015
# Epoch:91,Loss:0.0015
# Epoch:92,Loss:0.0014
# Epoch:93,Loss:0.0014
# Epoch:94,Loss:0.0013
# Epoch:95,Loss:0.0013
# Epoch:96,Loss:0.0012
# Epoch:97,Loss:0.0012
# Epoch:98,Loss:0.0011
# Epoch:99,Loss:0.0011
# Epoch:100,Loss:0.0011
# Epoch:101,Loss:0.0010
# Epoch:102,Loss:0.0010
# Epoch:103,Loss:0.0009
# Epoch:104,Loss:0.0009
# Epoch:105,Loss:0.0009
# Epoch:106,Loss:0.0009
# Epoch:107,Loss:0.0008
# Epoch:108,Loss:0.0008
# Epoch:109,Loss:0.0008
# Epoch:110,Loss:0.0008
# Epoch:111,Loss:0.0007
# Epoch:112,Loss:0.0007
# Epoch:113,Loss:0.0007
# Epoch:114,Loss:0.0006
# Epoch:115,Loss:0.0007
# Epoch:116,Loss:0.0006
# Epoch:117,Loss:0.0006
# Epoch:118,Loss:0.0006
# Epoch:119,Loss:0.0005
# Epoch:120,Loss:0.0006
# Epoch:121,Loss:0.0005
# Epoch:122,Loss:0.0005
# Epoch:123,Loss:0.0005
# Epoch:124,Loss:0.0005
# Epoch:125,Loss:0.0004
# Epoch:126,Loss:0.0004
# Epoch:127,Loss:0.0004
# Epoch:128,Loss:0.0004
# Epoch:129,Loss:0.0004
# Epoch:130,Loss:0.0004
# Epoch:131,Loss:0.0004
# Epoch:132,Loss:0.0004
# Epoch:133,Loss:0.0003
# Epoch:134,Loss:0.0003
# Epoch:135,Loss:0.0004
# Epoch:136,Loss:0.0003
# Epoch:137,Loss:0.0003
# Epoch:138,Loss:0.0003
# Epoch:139,Loss:0.0003
# Epoch:140,Loss:0.0003
# Epoch:141,Loss:0.0003
# Epoch:142,Loss:0.0003
# Epoch:143,Loss:0.0003
# Epoch:144,Loss:0.0003
# Epoch:145,Loss:0.0003
# Epoch:146,Loss:0.0003
# Epoch:147,Loss:0.0002
# Epoch:148,Loss:0.0003
# Epoch:149,Loss:0.0002
# Epoch:150,Loss:0.0002
# Epoch:151,Loss:0.0002
# Epoch:152,Loss:0.0002
# Epoch:153,Loss:0.0002
# Epoch:154,Loss:0.0002
# Epoch:155,Loss:0.0002
# Epoch:156,Loss:0.0002
# Epoch:157,Loss:0.0002
# Epoch:158,Loss:0.0002
# Epoch:159,Loss:0.0002
# Epoch:160,Loss:0.0002
# Epoch:161,Loss:0.0002
# Epoch:162,Loss:0.0002
# Epoch:163,Loss:0.0002
# Epoch:164,Loss:0.0002
# Epoch:165,Loss:0.0002
# Epoch:166,Loss:0.0001
# Epoch:167,Loss:0.0001
# Epoch:168,Loss:0.0001
# Epoch:169,Loss:0.0001
# Epoch:170,Loss:0.0001
# Epoch:171,Loss:0.0001
# Epoch:172,Loss:0.0001
# Epoch:173,Loss:0.0001
# Epoch:174,Loss:0.0001
# Epoch:175,Loss:0.0001
# Epoch:176,Loss:0.0001
# Epoch:177,Loss:0.0001
# Epoch:178,Loss:0.0001
# Epoch:179,Loss:0.0001
# Epoch:180,Loss:0.0001
# Epoch:181,Loss:0.0001
# Epoch:182,Loss:0.0001
# Epoch:183,Loss:0.0001
# Epoch:184,Loss:0.0001
# Epoch:185,Loss:0.0001
# Epoch:186,Loss:0.0001
# Epoch:187,Loss:0.0001
# Epoch:188,Loss:0.0001
# Epoch:189,Loss:0.0001
# Epoch:190,Loss:0.0001
# Epoch:191,Loss:0.0001
# Epoch:192,Loss:0.0001
# Epoch:193,Loss:0.0001
# Epoch:194,Loss:0.0001
# Epoch:195,Loss:0.0001
# Epoch:196,Loss:0.0001
# Epoch:197,Loss:0.0001
# Epoch:198,Loss:0.0001
# Epoch:199,Loss:0.0001
# Epoch:200,Loss:0.0001
# Epoch:201,Loss:0.0001
# Epoch:202,Loss:0.0001
# Epoch:203,Loss:0.0001
# Epoch:204,Loss:0.0001
# Epoch:205,Loss:0.0001
# Epoch:206,Loss:0.0000
# Epoch:207,Loss:0.0001
# Epoch:208,Loss:0.0001
# Epoch:209,Loss:0.0000
# Epoch:210,Loss:0.0000
# Epoch:211,Loss:0.0000
# Epoch:212,Loss:0.0000
# Epoch:213,Loss:0.0000
# Epoch:214,Loss:0.0000
# Epoch:215,Loss:0.0000
# Epoch:216,Loss:0.0000
# Epoch:217,Loss:0.0000
# Epoch:218,Loss:0.0000
# Epoch:219,Loss:0.0000
# Epoch:220,Loss:0.0000
# Epoch:221,Loss:0.0000
# Epoch:222,Loss:0.0000
# Epoch:223,Loss:0.0000
# Epoch:224,Loss:0.0000
# Epoch:225,Loss:0.0000
# Epoch:226,Loss:0.0000
# Epoch:227,Loss:0.0000
# Epoch:228,Loss:0.0000
# Epoch:229,Loss:0.0000
# Epoch:230,Loss:0.0000
# Epoch:231,Loss:0.0000
# Epoch:232,Loss:0.0000
# Epoch:233,Loss:0.0000
# Epoch:234,Loss:0.0000
# Epoch:235,Loss:0.0000
# Epoch:236,Loss:0.0000
# Epoch:237,Loss:0.0000
# Epoch:238,Loss:0.0000
# Epoch:239,Loss:0.0000
# Epoch:240,Loss:0.0000
# Epoch:241,Loss:0.0000
# Epoch:242,Loss:0.0000
# Epoch:243,Loss:0.0000
# Epoch:244,Loss:0.0000
# Epoch:245,Loss:0.0000
# Epoch:246,Loss:0.0000
# Epoch:247,Loss:0.0000
# Epoch:248,Loss:0.0000
# Epoch:249,Loss:0.0000
# Epoch:250,Loss:0.0000
# Epoch:251,Loss:0.0000
# Epoch:252,Loss:0.0000
# Epoch:253,Loss:0.0000
# Epoch:254,Loss:0.0000
# Epoch:255,Loss:0.0000
# Epoch:256,Loss:0.0000
# Epoch:257,Loss:0.0000
# Epoch:258,Loss:0.0000
# Epoch:259,Loss:0.0000
# Epoch:260,Loss:0.0000
# Epoch:261,Loss:0.0000
# Epoch:262,Loss:0.0000
# Epoch:263,Loss:0.0000
# Epoch:264,Loss:0.0000
# Epoch:265,Loss:0.0000
# Epoch:266,Loss:0.0000
# Epoch:267,Loss:0.0000
# Epoch:268,Loss:0.0000
# Epoch:269,Loss:0.0000
# Epoch:270,Loss:0.0000
# Epoch:271,Loss:0.0000
# Epoch:272,Loss:0.0000
# Epoch:273,Loss:0.0000
# Epoch:274,Loss:0.0000
# Epoch:275,Loss:0.0000
# Epoch:276,Loss:0.0000
# Epoch:277,Loss:0.0000
# Epoch:278,Loss:0.0000
# Epoch:279,Loss:0.0000
# Epoch:280,Loss:0.0000
# Epoch:281,Loss:0.0000
# Epoch:282,Loss:0.0000
# Epoch:283,Loss:0.0000
# Epoch:284,Loss:0.0000
# Epoch:285,Loss:0.0000
# Epoch:286,Loss:0.0000
# Epoch:287,Loss:0.0000
# Epoch:288,Loss:0.0000
# Epoch:289,Loss:0.0000
# Epoch:290,Loss:0.0000
# Epoch:291,Loss:0.0000
# Epoch:292,Loss:0.0000
# Epoch:293,Loss:0.0000
# Epoch:294,Loss:0.0000
# Epoch:295,Loss:0.0000
# Epoch:296,Loss:0.0000
# Epoch:297,Loss:0.0000
# Epoch:298,Loss:0.0000
# Epoch:299,Loss:0.0000
# Epoch:300,Loss:0.0000
# Epoch:301,Loss:0.0000
# Epoch:302,Loss:0.0000
# Epoch:303,Loss:0.0000
# Epoch:304,Loss:0.0000
# Epoch:305,Loss:0.0000
# Epoch:306,Loss:0.0000
# Epoch:307,Loss:0.0000
# Epoch:308,Loss:0.0000
# Epoch:309,Loss:0.0000
# Epoch:310,Loss:0.0000
# Epoch:311,Loss:0.0000
# Epoch:312,Loss:0.0000
# Epoch:313,Loss:0.0000
# Epoch:314,Loss:0.0000
# Epoch:315,Loss:0.0000
# Epoch:316,Loss:0.0000
# Epoch:317,Loss:0.0000
# Epoch:318,Loss:0.0000
# Epoch:319,Loss:0.0000
# Epoch:320,Loss:0.0000
# Epoch:321,Loss:0.0000
# Epoch:322,Loss:0.0000
# Epoch:323,Loss:0.0000
# Epoch:324,Loss:0.0000
# Epoch:325,Loss:0.0000
# Epoch:326,Loss:0.0000
# Epoch:327,Loss:0.0000
# Epoch:328,Loss:0.0000
# Epoch:329,Loss:0.0000
# Epoch:330,Loss:0.0000
# Epoch:331,Loss:0.0000
# Epoch:332,Loss:0.0000
# Epoch:333,Loss:0.0000
# Epoch:334,Loss:0.0000
# Epoch:335,Loss:0.0000
# Epoch:336,Loss:0.0000
# Epoch:337,Loss:0.0000
# Epoch:338,Loss:0.0000
# Epoch:339,Loss:0.0000
# Epoch:340,Loss:0.0000
# Epoch:341,Loss:0.0000
# Epoch:342,Loss:0.0000
# Epoch:343,Loss:0.0000
# Epoch:344,Loss:0.0000
# Epoch:345,Loss:0.0000
# Epoch:346,Loss:0.0000
# Epoch:347,Loss:0.0000
# Epoch:348,Loss:0.0000
# Epoch:349,Loss:0.0000
# Epoch:350,Loss:0.0000
# Epoch:351,Loss:0.0000
# Epoch:352,Loss:0.0000
# Epoch:353,Loss:0.0000
# Epoch:354,Loss:0.0000
# Epoch:355,Loss:0.0000
# Epoch:356,Loss:0.0000
# Epoch:357,Loss:0.0000
# Epoch:358,Loss:0.0000
# Epoch:359,Loss:0.0000
# Epoch:360,Loss:0.0000
# Epoch:361,Loss:0.0000
# Epoch:362,Loss:0.0000
# Epoch:363,Loss:0.0000
# Epoch:364,Loss:0.0000
# Epoch:365,Loss:0.0000
# Epoch:366,Loss:0.0000
# Epoch:367,Loss:0.0000
# Epoch:368,Loss:0.0000
# Epoch:369,Loss:0.0000
# Epoch:370,Loss:0.0000
# Epoch:371,Loss:0.0000
# Epoch:372,Loss:0.0000
# Epoch:373,Loss:0.0000
# Epoch:374,Loss:0.0000
# Epoch:375,Loss:0.0000
# Epoch:376,Loss:0.0000
# Epoch:377,Loss:0.0000
# Epoch:378,Loss:0.0000
# Epoch:379,Loss:0.0000
# Epoch:380,Loss:0.0000
# Epoch:381,Loss:0.0000
# Epoch:382,Loss:0.0000
# Epoch:383,Loss:0.0000
# Epoch:384,Loss:0.0000
# Epoch:385,Loss:0.0000
# Epoch:386,Loss:0.0000
# Epoch:387,Loss:0.0000
# Epoch:388,Loss:0.0000
# Epoch:389,Loss:0.0000
# Epoch:390,Loss:0.0000
# Epoch:391,Loss:0.0000
# Epoch:392,Loss:0.0000
# Epoch:393,Loss:0.0000
# Epoch:394,Loss:0.0000
# Epoch:395,Loss:0.0000
# Epoch:396,Loss:0.0000
# Epoch:397,Loss:0.0000
# Epoch:398,Loss:0.0000
# Epoch:399,Loss:0.0000
# Epoch:400,Loss:0.0000
# Epoch:401,Loss:0.0000
# Epoch:402,Loss:0.0000
# Epoch:403,Loss:0.0000
# Epoch:404,Loss:0.0000
# Epoch:405,Loss:0.0000
# Epoch:406,Loss:0.0000
# Epoch:407,Loss:0.0000
# Epoch:408,Loss:0.0000
# Epoch:409,Loss:0.0000
# Epoch:410,Loss:0.0000
# Epoch:411,Loss:0.0000
# Epoch:412,Loss:0.0000
# Epoch:413,Loss:0.0000
# Epoch:414,Loss:0.0000
# Epoch:415,Loss:0.0000
# Epoch:416,Loss:0.0000
# Epoch:417,Loss:0.0000
# Epoch:418,Loss:0.0000
# Epoch:419,Loss:0.0000
# Epoch:420,Loss:0.0000
# Epoch:421,Loss:0.0000
# Epoch:422,Loss:0.0000
# Epoch:423,Loss:0.0000
# Epoch:424,Loss:0.0000
# Epoch:425,Loss:0.0000
# Epoch:426,Loss:0.0000
# Epoch:427,Loss:0.0000
# Epoch:428,Loss:0.0000
# Epoch:429,Loss:0.0000
# Epoch:430,Loss:0.0000
# Epoch:431,Loss:0.0000
# Epoch:432,Loss:0.0000
# Epoch:433,Loss:0.0000
# Epoch:434,Loss:0.0000
# Epoch:435,Loss:0.0000
# Epoch:436,Loss:0.0000
# Epoch:437,Loss:0.0000
# Epoch:438,Loss:0.0000
# Epoch:439,Loss:0.0000
# Epoch:440,Loss:0.0000
# Epoch:441,Loss:0.0000
# Epoch:442,Loss:0.0000
# Epoch:443,Loss:0.0000
# Epoch:444,Loss:0.0000
# Epoch:445,Loss:0.0000
# Epoch:446,Loss:0.0000
# Epoch:447,Loss:0.0000
# Epoch:448,Loss:0.0000
# Epoch:449,Loss:0.0000
# Epoch:450,Loss:0.0000
# Epoch:451,Loss:0.0000
# Epoch:452,Loss:0.0000
# Epoch:453,Loss:0.0000
# Epoch:454,Loss:0.0000
# Epoch:455,Loss:0.0000
# Epoch:456,Loss:0.0000
# Epoch:457,Loss:0.0000
# Epoch:458,Loss:0.0000
# Epoch:459,Loss:0.0000
# Epoch:460,Loss:0.0000
# Epoch:461,Loss:0.0000
# Epoch:462,Loss:0.0000
# Epoch:463,Loss:0.0000
# Epoch:464,Loss:0.0000
# Epoch:465,Loss:0.0000
# Epoch:466,Loss:0.0000
# Epoch:467,Loss:0.0000
# Epoch:468,Loss:0.0000
# Epoch:469,Loss:0.0000
# Epoch:470,Loss:0.0000
# Epoch:471,Loss:0.0000
# Epoch:472,Loss:0.0000
# Epoch:473,Loss:0.0000
# Epoch:474,Loss:0.0000
# Epoch:475,Loss:0.0000
# Epoch:476,Loss:0.0000
# Epoch:477,Loss:0.0000
# Epoch:478,Loss:0.0000
# Epoch:479,Loss:0.0000
# Epoch:480,Loss:0.0000
# Epoch:481,Loss:0.0000
# Epoch:482,Loss:0.0000
# Epoch:483,Loss:0.0000
# Epoch:484,Loss:0.0000
# Epoch:485,Loss:0.0000
# Epoch:486,Loss:0.0000
# Epoch:487,Loss:0.0000
# Epoch:488,Loss:0.0000
# Epoch:489,Loss:0.0000
# Epoch:490,Loss:0.0000
# Epoch:491,Loss:0.0000
# Epoch:492,Loss:0.0000
# Epoch:493,Loss:0.0000
# Epoch:494,Loss:0.0000
# Epoch:495,Loss:0.0000
# Epoch:496,Loss:0.0000
# Epoch:497,Loss:0.0000
# Epoch:498,Loss:0.0000
# Epoch:499,Loss:0.0000
# Epoch:500,Loss:0.0000
# erro =  0.5666666666666667
# acerto =  0.43333333333333335
# (40, 30)
# (40,)
# (50, 30)
# (50,)
# Input_Train torch.Size([4, 10, 30])
# Train_Labels torch.Size([4, 10, 1])
# Input_test torch.Size([5, 10, 30])
# test_Labels torch.Size([5, 10, 1])
# Epoch:1,Loss:0.4738
# Epoch:2,Loss:0.5568
# Epoch:3,Loss:0.3156
# Epoch:4,Loss:0.2527
# Epoch:5,Loss:0.2799
# Epoch:6,Loss:0.2387
# Epoch:7,Loss:0.2241
# Epoch:8,Loss:0.2357
# Epoch:9,Loss:0.2204
# Epoch:10,Loss:0.2176
# Epoch:11,Loss:0.2188
# Epoch:12,Loss:0.2116
# Epoch:13,Loss:0.2115
# Epoch:14,Loss:0.1967
# Epoch:15,Loss:0.1922
# Epoch:16,Loss:0.1751
# Epoch:17,Loss:0.1716
# Epoch:18,Loss:0.1516
# Epoch:19,Loss:0.1413
# Epoch:20,Loss:0.1327
# Epoch:21,Loss:0.1162
# Epoch:22,Loss:0.1068
# Epoch:23,Loss:0.1040
# Epoch:24,Loss:0.0969
# Epoch:25,Loss:0.0822
# Epoch:26,Loss:0.0709
# Epoch:27,Loss:0.0682
# Epoch:28,Loss:0.0877
# Epoch:29,Loss:0.1078
# Epoch:30,Loss:0.0611
# Epoch:31,Loss:0.0998
# Epoch:32,Loss:0.0588
# Epoch:33,Loss:0.1836
# Epoch:34,Loss:0.0582
# Epoch:35,Loss:0.0683
# Epoch:36,Loss:0.0836
# Epoch:37,Loss:0.0475
# Epoch:38,Loss:0.0399
# Epoch:39,Loss:0.0643
# Epoch:40,Loss:0.0572
# Epoch:41,Loss:0.0342
# Epoch:42,Loss:0.0336
# Epoch:43,Loss:0.0596
# Epoch:44,Loss:0.0602
# Epoch:45,Loss:0.0268
# Epoch:46,Loss:0.0266
# Epoch:47,Loss:0.0622
# Epoch:48,Loss:0.0547
# Epoch:49,Loss:0.0256
# Epoch:50,Loss:0.0191
# Epoch:51,Loss:0.0612
# Epoch:52,Loss:0.0333
# Epoch:53,Loss:0.0245
# Epoch:54,Loss:0.0173
# Epoch:55,Loss:0.0551
# Epoch:56,Loss:0.0189
# Epoch:57,Loss:0.0200
# Epoch:58,Loss:0.0190
# Epoch:59,Loss:0.0363
# Epoch:60,Loss:0.0114
# Epoch:61,Loss:0.0099
# Epoch:62,Loss:0.0167
# Epoch:63,Loss:0.0249
# Epoch:64,Loss:0.0072
# Epoch:65,Loss:0.0072
# Epoch:66,Loss:0.0141
# Epoch:67,Loss:0.0147
# Epoch:68,Loss:0.0045
# Epoch:69,Loss:0.0040
# Epoch:70,Loss:0.0112
# Epoch:71,Loss:0.0060
# Epoch:72,Loss:0.0037
# Epoch:73,Loss:0.0045
# Epoch:74,Loss:0.0086
# Epoch:75,Loss:0.0027
# Epoch:76,Loss:0.0018
# Epoch:77,Loss:0.0049
# Epoch:78,Loss:0.0063
# Epoch:79,Loss:0.0017
# Epoch:80,Loss:0.0012
# Epoch:81,Loss:0.0041
# Epoch:82,Loss:0.0034
# Epoch:83,Loss:0.0011
# Epoch:84,Loss:0.0008
# Epoch:85,Loss:0.0033
# Epoch:86,Loss:0.0020
# Epoch:87,Loss:0.0008
# Epoch:88,Loss:0.0006
# Epoch:89,Loss:0.0031
# Epoch:90,Loss:0.0020
# Epoch:91,Loss:0.0010
# Epoch:92,Loss:0.0004
# Epoch:93,Loss:0.0031
# Epoch:94,Loss:0.0020
# Epoch:95,Loss:0.0009
# Epoch:96,Loss:0.0002
# Epoch:97,Loss:0.0024
# Epoch:98,Loss:0.0012
# Epoch:99,Loss:0.0008
# Epoch:100,Loss:0.0002
# Epoch:101,Loss:0.0011
# Epoch:102,Loss:0.0006
# Epoch:103,Loss:0.0004
# Epoch:104,Loss:0.0001
# Epoch:105,Loss:0.0008
# Epoch:106,Loss:0.0002
# Epoch:107,Loss:0.0002
# Epoch:108,Loss:0.0001
# Epoch:109,Loss:0.0002
# Epoch:110,Loss:0.0001
# Epoch:111,Loss:0.0001
# Epoch:112,Loss:0.0001
# Epoch:113,Loss:0.0002
# Epoch:114,Loss:0.0002
# Epoch:115,Loss:0.0001
# Epoch:116,Loss:0.0001
# Epoch:117,Loss:0.0002
# Epoch:118,Loss:0.0002
# Epoch:119,Loss:0.0001
# Epoch:120,Loss:0.0001
# Epoch:121,Loss:0.0003
# Epoch:122,Loss:0.0002
# Epoch:123,Loss:0.0002
# Epoch:124,Loss:0.0001
# Epoch:125,Loss:0.0002
# Epoch:126,Loss:0.0001
# Epoch:127,Loss:0.0002
# Epoch:128,Loss:0.0000
# Epoch:129,Loss:0.0001
# Epoch:130,Loss:0.0000
# Epoch:131,Loss:0.0001
# Epoch:132,Loss:0.0000
# Epoch:133,Loss:0.0001
# Epoch:134,Loss:0.0000
# Epoch:135,Loss:0.0001
# Epoch:136,Loss:0.0000
# Epoch:137,Loss:0.0002
# Epoch:138,Loss:0.0001
# Epoch:139,Loss:0.0001
# Epoch:140,Loss:0.0002
# Epoch:141,Loss:0.0001
# Epoch:142,Loss:0.0001
# Epoch:143,Loss:0.0001
# Epoch:144,Loss:0.0000
# Epoch:145,Loss:0.0001
# Epoch:146,Loss:0.0000
# Epoch:147,Loss:0.0000
# Epoch:148,Loss:0.0000
# Epoch:149,Loss:0.0000
# Epoch:150,Loss:0.0000
# Epoch:151,Loss:0.0000
# Epoch:152,Loss:0.0001
# Epoch:153,Loss:0.0000
# Epoch:154,Loss:0.0002
# Epoch:155,Loss:0.0000
# Epoch:156,Loss:0.0002
# Epoch:157,Loss:0.0000
# Epoch:158,Loss:0.0003
# Epoch:159,Loss:0.0000
# Epoch:160,Loss:0.0001
# Epoch:161,Loss:0.0000
# Epoch:162,Loss:0.0002
# Epoch:163,Loss:0.0000
# Epoch:164,Loss:0.0000
# Epoch:165,Loss:0.0000
# Epoch:166,Loss:0.0001
# Epoch:167,Loss:0.0000
# Epoch:168,Loss:0.0000
# Epoch:169,Loss:0.0000
# Epoch:170,Loss:0.0000
# Epoch:171,Loss:0.0000
# Epoch:172,Loss:0.0000
# Epoch:173,Loss:0.0001
# Epoch:174,Loss:0.0000
# Epoch:175,Loss:0.0002
# Epoch:176,Loss:0.0000
# Epoch:177,Loss:0.0001
# Epoch:178,Loss:0.0001
# Epoch:179,Loss:0.0003
# Epoch:180,Loss:0.0003
# Epoch:181,Loss:0.0001
# Epoch:182,Loss:0.0003
# Epoch:183,Loss:0.0001
# Epoch:184,Loss:0.0004
# Epoch:185,Loss:0.0000
# Epoch:186,Loss:0.0001
# Epoch:187,Loss:0.0000
# Epoch:188,Loss:0.0001
# Epoch:189,Loss:0.0000
# Epoch:190,Loss:0.0000
# Epoch:191,Loss:0.0000
# Epoch:192,Loss:0.0000
# Epoch:193,Loss:0.0000
# Epoch:194,Loss:0.0000
# Epoch:195,Loss:0.0000
# Epoch:196,Loss:0.0000
# Epoch:197,Loss:0.0000
# Epoch:198,Loss:0.0000
# Epoch:199,Loss:0.0000
# Epoch:200,Loss:0.0001
# Epoch:201,Loss:0.0000
# Epoch:202,Loss:0.0001
# Epoch:203,Loss:0.0001
# Epoch:204,Loss:0.0001
# Epoch:205,Loss:0.0003
# Epoch:206,Loss:0.0000
# Epoch:207,Loss:0.0005
# Epoch:208,Loss:0.0001
# Epoch:209,Loss:0.0015
# Epoch:210,Loss:0.0030
# Epoch:211,Loss:0.0003
# Epoch:212,Loss:0.0039
# Epoch:213,Loss:0.0091
# Epoch:214,Loss:0.0068
# Epoch:215,Loss:0.1303
# Epoch:216,Loss:0.0868
# Epoch:217,Loss:0.1428
# Epoch:218,Loss:0.0439
# Epoch:219,Loss:0.0446
# Epoch:220,Loss:0.0345
# Epoch:221,Loss:0.0763
# Epoch:222,Loss:0.0257
# Epoch:223,Loss:0.0370
# Epoch:224,Loss:0.0110
# Epoch:225,Loss:0.0042
# Epoch:226,Loss:0.0092
# Epoch:227,Loss:0.0017
# Epoch:228,Loss:0.0008
# Epoch:229,Loss:0.0013
# Epoch:230,Loss:0.0005
# Epoch:231,Loss:0.0010
# Epoch:232,Loss:0.0003
# Epoch:233,Loss:0.0006
# Epoch:234,Loss:0.0001
# Epoch:235,Loss:0.0002
# Epoch:236,Loss:0.0001
# Epoch:237,Loss:0.0001
# Epoch:238,Loss:0.0001
# Epoch:239,Loss:0.0001
# Epoch:240,Loss:0.0001
# Epoch:241,Loss:0.0000
# Epoch:242,Loss:0.0000
# Epoch:243,Loss:0.0000
# Epoch:244,Loss:0.0000
# Epoch:245,Loss:0.0000
# Epoch:246,Loss:0.0000
# Epoch:247,Loss:0.0000
# Epoch:248,Loss:0.0000
# Epoch:249,Loss:0.0000
# Epoch:250,Loss:0.0000
# Epoch:251,Loss:0.0000
# Epoch:252,Loss:0.0000
# Epoch:253,Loss:0.0000
# Epoch:254,Loss:0.0000
# Epoch:255,Loss:0.0000
# Epoch:256,Loss:0.0000
# Epoch:257,Loss:0.0000
# Epoch:258,Loss:0.0000
# Epoch:259,Loss:0.0000
# Epoch:260,Loss:0.0000
# Epoch:261,Loss:0.0000
# Epoch:262,Loss:0.0000
# Epoch:263,Loss:0.0000
# Epoch:264,Loss:0.0000
# Epoch:265,Loss:0.0000
# Epoch:266,Loss:0.0000
# Epoch:267,Loss:0.0000
# Epoch:268,Loss:0.0000
# Epoch:269,Loss:0.0000
# Epoch:270,Loss:0.0000
# Epoch:271,Loss:0.0000
# Epoch:272,Loss:0.0000
# Epoch:273,Loss:0.0000
# Epoch:274,Loss:0.0000
# Epoch:275,Loss:0.0000
# Epoch:276,Loss:0.0000
# Epoch:277,Loss:0.0000
# Epoch:278,Loss:0.0000
# Epoch:279,Loss:0.0000
# Epoch:280,Loss:0.0000
# Epoch:281,Loss:0.0000
# Epoch:282,Loss:0.0000
# Epoch:283,Loss:0.0000
# Epoch:284,Loss:0.0000
# Epoch:285,Loss:0.0000
# Epoch:286,Loss:0.0000
# Epoch:287,Loss:0.0000
# Epoch:288,Loss:0.0000
# Epoch:289,Loss:0.0000
# Epoch:290,Loss:0.0000
# Epoch:291,Loss:0.0000
# Epoch:292,Loss:0.0000
# Epoch:293,Loss:0.0000
# Epoch:294,Loss:0.0000
# Epoch:295,Loss:0.0000
# Epoch:296,Loss:0.0000
# Epoch:297,Loss:0.0000
# Epoch:298,Loss:0.0000
# Epoch:299,Loss:0.0000
# Epoch:300,Loss:0.0000
# Epoch:301,Loss:0.0000
# Epoch:302,Loss:0.0000
# Epoch:303,Loss:0.0000
# Epoch:304,Loss:0.0000
# Epoch:305,Loss:0.0000
# Epoch:306,Loss:0.0000
# Epoch:307,Loss:0.0000
# Epoch:308,Loss:0.0000
# Epoch:309,Loss:0.0000
# Epoch:310,Loss:0.0000
# Epoch:311,Loss:0.0000
# Epoch:312,Loss:0.0000
# Epoch:313,Loss:0.0000
# Epoch:314,Loss:0.0001
# Epoch:315,Loss:0.0000
# Epoch:316,Loss:0.0000
# Epoch:317,Loss:0.0000
# Epoch:318,Loss:0.0000
# Epoch:319,Loss:0.0000
# Epoch:320,Loss:0.0000
# Epoch:321,Loss:0.0000
# Epoch:322,Loss:0.0000
# Epoch:323,Loss:0.0000
# Epoch:324,Loss:0.0000
# Epoch:325,Loss:0.0000
# Epoch:326,Loss:0.0000
# Epoch:327,Loss:0.0000
# Epoch:328,Loss:0.0000
# Epoch:329,Loss:0.0000
# Epoch:330,Loss:0.0000
# Epoch:331,Loss:0.0000
# Epoch:332,Loss:0.0000
# Epoch:333,Loss:0.0000
# Epoch:334,Loss:0.0000
# Epoch:335,Loss:0.0000
# Epoch:336,Loss:0.0000
# Epoch:337,Loss:0.0001
# Epoch:338,Loss:0.0000
# Epoch:339,Loss:0.0001
# Epoch:340,Loss:0.0000
# Epoch:341,Loss:0.0000
# Epoch:342,Loss:0.0000
# Epoch:343,Loss:0.0000
# Epoch:344,Loss:0.0000
# Epoch:345,Loss:0.0000
# Epoch:346,Loss:0.0000
# Epoch:347,Loss:0.0000
# Epoch:348,Loss:0.0000
# Epoch:349,Loss:0.0000
# Epoch:350,Loss:0.0000
# Epoch:351,Loss:0.0000
# Epoch:352,Loss:0.0000
# Epoch:353,Loss:0.0000
# Epoch:354,Loss:0.0000
# Epoch:355,Loss:0.0000
# Epoch:356,Loss:0.0000
# Epoch:357,Loss:0.0000
# Epoch:358,Loss:0.0000
# Epoch:359,Loss:0.0000
# Epoch:360,Loss:0.0000
# Epoch:361,Loss:0.0000
# Epoch:362,Loss:0.0000
# Epoch:363,Loss:0.0001
# Epoch:364,Loss:0.0001
# Epoch:365,Loss:0.0000
# Epoch:366,Loss:0.0001
# Epoch:367,Loss:0.0000
# Epoch:368,Loss:0.0001
# Epoch:369,Loss:0.0000
# Epoch:370,Loss:0.0000
# Epoch:371,Loss:0.0000
# Epoch:372,Loss:0.0000
# Epoch:373,Loss:0.0000
# Epoch:374,Loss:0.0000
# Epoch:375,Loss:0.0000
# Epoch:376,Loss:0.0000
# Epoch:377,Loss:0.0000
# Epoch:378,Loss:0.0000
# Epoch:379,Loss:0.0000
# Epoch:380,Loss:0.0000
# Epoch:381,Loss:0.0000
# Epoch:382,Loss:0.0000
# Epoch:383,Loss:0.0000
# Epoch:384,Loss:0.0000
# Epoch:385,Loss:0.0000
# Epoch:386,Loss:0.0000
# Epoch:387,Loss:0.0000
# Epoch:388,Loss:0.0000
# Epoch:389,Loss:0.0000
# Epoch:390,Loss:0.0000
# Epoch:391,Loss:0.0000
# Epoch:392,Loss:0.0000
# Epoch:393,Loss:0.0001
# Epoch:394,Loss:0.0000
# Epoch:395,Loss:0.0002
# Epoch:396,Loss:0.0000
# Epoch:397,Loss:0.0002
# Epoch:398,Loss:0.0000
# Epoch:399,Loss:0.0001
# Epoch:400,Loss:0.0000
# Epoch:401,Loss:0.0001
# Epoch:402,Loss:0.0000
# Epoch:403,Loss:0.0000
# Epoch:404,Loss:0.0000
# Epoch:405,Loss:0.0000
# Epoch:406,Loss:0.0000
# Epoch:407,Loss:0.0000
# Epoch:408,Loss:0.0000
# Epoch:409,Loss:0.0000
# Epoch:410,Loss:0.0000
# Epoch:411,Loss:0.0000
# Epoch:412,Loss:0.0000
# Epoch:413,Loss:0.0000
# Epoch:414,Loss:0.0000
# Epoch:415,Loss:0.0000
# Epoch:416,Loss:0.0000
# Epoch:417,Loss:0.0000
# Epoch:418,Loss:0.0000
# Epoch:419,Loss:0.0000
# Epoch:420,Loss:0.0000
# Epoch:421,Loss:0.0000
# Epoch:422,Loss:0.0000
# Epoch:423,Loss:0.0000
# Epoch:424,Loss:0.0000
# Epoch:425,Loss:0.0000
# Epoch:426,Loss:0.0000
# Epoch:427,Loss:0.0000
# Epoch:428,Loss:0.0000
# Epoch:429,Loss:0.0000
# Epoch:430,Loss:0.0000
# Epoch:431,Loss:0.0000
# Epoch:432,Loss:0.0000
# Epoch:433,Loss:0.0000
# Epoch:434,Loss:0.0000
# Epoch:435,Loss:0.0000
# Epoch:436,Loss:0.0000
# Epoch:437,Loss:0.0001
# Epoch:438,Loss:0.0000
# Epoch:439,Loss:0.0002
# Epoch:440,Loss:0.0001
# Epoch:441,Loss:0.0003
# Epoch:442,Loss:0.0004
# Epoch:443,Loss:0.0001
# Epoch:444,Loss:0.0006
# Epoch:445,Loss:0.0000
# Epoch:446,Loss:0.0013
# Epoch:447,Loss:0.0002
# Epoch:448,Loss:0.0011
# Epoch:449,Loss:0.0008
# Epoch:450,Loss:0.0016
# Epoch:451,Loss:0.0024
# Epoch:452,Loss:0.0013
# Epoch:453,Loss:0.0028
# Epoch:454,Loss:0.0017
# Epoch:455,Loss:0.0061
# Epoch:456,Loss:0.0015
# Epoch:457,Loss:0.0026
# Epoch:458,Loss:0.0008
# Epoch:459,Loss:0.0013
# Epoch:460,Loss:0.0015
# Epoch:461,Loss:0.0001
# Epoch:462,Loss:0.0003
# Epoch:463,Loss:0.0001
# Epoch:464,Loss:0.0000
# Epoch:465,Loss:0.0001
# Epoch:466,Loss:0.0001
# Epoch:467,Loss:0.0000
# Epoch:468,Loss:0.0000
# Epoch:469,Loss:0.0000
# Epoch:470,Loss:0.0000
# Epoch:471,Loss:0.0000
# Epoch:472,Loss:0.0000
# Epoch:473,Loss:0.0000
# Epoch:474,Loss:0.0000
# Epoch:475,Loss:0.0000
# Epoch:476,Loss:0.0000
# Epoch:477,Loss:0.0000
# Epoch:478,Loss:0.0000
# Epoch:479,Loss:0.0000
# Epoch:480,Loss:0.0000
# Epoch:481,Loss:0.0000
# Epoch:482,Loss:0.0000
# Epoch:483,Loss:0.0000
# Epoch:484,Loss:0.0000
# Epoch:485,Loss:0.0000
# Epoch:486,Loss:0.0000
# Epoch:487,Loss:0.0000
# Epoch:488,Loss:0.0000
# Epoch:489,Loss:0.0000
# Epoch:490,Loss:0.0000
# Epoch:491,Loss:0.0000
# Epoch:492,Loss:0.0000
# Epoch:493,Loss:0.0000
# Epoch:494,Loss:0.0000
# Epoch:495,Loss:0.0000
# Epoch:496,Loss:0.0000
# Epoch:497,Loss:0.0000
# Epoch:498,Loss:0.0000
# Epoch:499,Loss:0.0000
# Epoch:500,Loss:0.0000
# erro =  0.62
# acerto =  0.38
# (50, 30)
# (50,)
# (40, 30)
# (40,)
# Input_Train torch.Size([5, 10, 30])
# Train_Labels torch.Size([5, 10, 1])
# Input_test torch.Size([4, 10, 30])
# test_Labels torch.Size([4, 10, 1])
# Epoch:1,Loss:0.5246
# Epoch:2,Loss:0.2739
# Epoch:3,Loss:0.2223
# Epoch:4,Loss:0.2368
# Epoch:5,Loss:0.2532
# Epoch:6,Loss:0.2027
# Epoch:7,Loss:0.3376
# Epoch:8,Loss:0.2361
# Epoch:9,Loss:0.1810
# Epoch:10,Loss:0.1646
# Epoch:11,Loss:0.1372
# Epoch:12,Loss:0.1670
# Epoch:13,Loss:0.1347
# Epoch:14,Loss:0.1396
# Epoch:15,Loss:0.1813
# Epoch:16,Loss:0.1772
# Epoch:17,Loss:0.0551
# Epoch:18,Loss:0.0561
# Epoch:19,Loss:0.0880
# Epoch:20,Loss:0.0333
# Epoch:21,Loss:0.0178
# Epoch:22,Loss:0.0521
# Epoch:23,Loss:0.1479
# Epoch:24,Loss:0.1089
# Epoch:25,Loss:0.0375
# Epoch:26,Loss:0.0374
# Epoch:27,Loss:0.0787
# Epoch:28,Loss:0.0086
# Epoch:29,Loss:0.0087
# Epoch:30,Loss:0.0321
# Epoch:31,Loss:0.0124
# Epoch:32,Loss:0.0068
# Epoch:33,Loss:0.0133
# Epoch:34,Loss:0.0075
# Epoch:35,Loss:0.0046
# Epoch:36,Loss:0.0095
# Epoch:37,Loss:0.0056
# Epoch:38,Loss:0.0033
# Epoch:39,Loss:0.0061
# Epoch:40,Loss:0.0034
# Epoch:41,Loss:0.0029
# Epoch:42,Loss:0.0048
# Epoch:43,Loss:0.0030
# Epoch:44,Loss:0.0024
# Epoch:45,Loss:0.0034
# Epoch:46,Loss:0.0022
# Epoch:47,Loss:0.0024
# Epoch:48,Loss:0.0023
# Epoch:49,Loss:0.0018
# Epoch:50,Loss:0.0021
# Epoch:51,Loss:0.0021
# Epoch:52,Loss:0.0017
# Epoch:53,Loss:0.0017
# Epoch:54,Loss:0.0019
# Epoch:55,Loss:0.0017
# Epoch:56,Loss:0.0013
# Epoch:57,Loss:0.0016
# Epoch:58,Loss:0.0019
# Epoch:59,Loss:0.0014
# Epoch:60,Loss:0.0011
# Epoch:61,Loss:0.0016
# Epoch:62,Loss:0.0016
# Epoch:63,Loss:0.0011
# Epoch:64,Loss:0.0012
# Epoch:65,Loss:0.0012
# Epoch:66,Loss:0.0011
# Epoch:67,Loss:0.0011
# Epoch:68,Loss:0.0010
# Epoch:69,Loss:0.0010
# Epoch:70,Loss:0.0009
# Epoch:71,Loss:0.0009
# Epoch:72,Loss:0.0011
# Epoch:73,Loss:0.0010
# Epoch:74,Loss:0.0007
# Epoch:75,Loss:0.0009
# Epoch:76,Loss:0.0016
# Epoch:77,Loss:0.0008
# Epoch:78,Loss:0.0007
# Epoch:79,Loss:0.0011
# Epoch:80,Loss:0.0007
# Epoch:81,Loss:0.0007
# Epoch:82,Loss:0.0008
# Epoch:83,Loss:0.0006
# Epoch:84,Loss:0.0006
# Epoch:85,Loss:0.0006
# Epoch:86,Loss:0.0005
# Epoch:87,Loss:0.0005
# Epoch:88,Loss:0.0006
# Epoch:89,Loss:0.0005
# Epoch:90,Loss:0.0004
# Epoch:91,Loss:0.0005
# Epoch:92,Loss:0.0006
# Epoch:93,Loss:0.0004
# Epoch:94,Loss:0.0004
# Epoch:95,Loss:0.0005
# Epoch:96,Loss:0.0010
# Epoch:97,Loss:0.0005
# Epoch:98,Loss:0.0003
# Epoch:99,Loss:0.0006
# Epoch:100,Loss:0.0008
# Epoch:101,Loss:0.0004
# Epoch:102,Loss:0.0005
# Epoch:103,Loss:0.0004
# Epoch:104,Loss:0.0004
# Epoch:105,Loss:0.0004
# Epoch:106,Loss:0.0003
# Epoch:107,Loss:0.0003
# Epoch:108,Loss:0.0003
# Epoch:109,Loss:0.0003
# Epoch:110,Loss:0.0003
# Epoch:111,Loss:0.0003
# Epoch:112,Loss:0.0003
# Epoch:113,Loss:0.0002
# Epoch:114,Loss:0.0003
# Epoch:115,Loss:0.0003
# Epoch:116,Loss:0.0002
# Epoch:117,Loss:0.0002
# Epoch:118,Loss:0.0003
# Epoch:119,Loss:0.0003
# Epoch:120,Loss:0.0002
# Epoch:121,Loss:0.0002
# Epoch:122,Loss:0.0004
# Epoch:123,Loss:0.0002
# Epoch:124,Loss:0.0002
# Epoch:125,Loss:0.0003
# Epoch:126,Loss:0.0009
# Epoch:127,Loss:0.0003
# Epoch:128,Loss:0.0002
# Epoch:129,Loss:0.0004
# Epoch:130,Loss:0.0002
# Epoch:131,Loss:0.0002
# Epoch:132,Loss:0.0002
# Epoch:133,Loss:0.0001
# Epoch:134,Loss:0.0002
# Epoch:135,Loss:0.0001
# Epoch:136,Loss:0.0001
# Epoch:137,Loss:0.0002
# Epoch:138,Loss:0.0001
# Epoch:139,Loss:0.0001
# Epoch:140,Loss:0.0001
# Epoch:141,Loss:0.0001
# Epoch:142,Loss:0.0001
# Epoch:143,Loss:0.0001
# Epoch:144,Loss:0.0001
# Epoch:145,Loss:0.0001
# Epoch:146,Loss:0.0001
# Epoch:147,Loss:0.0001
# Epoch:148,Loss:0.0001
# Epoch:149,Loss:0.0001
# Epoch:150,Loss:0.0001
# Epoch:151,Loss:0.0001
# Epoch:152,Loss:0.0001
# Epoch:153,Loss:0.0001
# Epoch:154,Loss:0.0001
# Epoch:155,Loss:0.0001
# Epoch:156,Loss:0.0001
# Epoch:157,Loss:0.0001
# Epoch:158,Loss:0.0002
# Epoch:159,Loss:0.0001
# ...
# Epoch:279,Loss:0.0000
# Epoch:280,Loss:0.0000
# Epoch:281,Loss:0.0000
# Epoch:282,Loss:0.0000
# Epoch:283,Loss:0.0000
# Epoch:284,Loss:0.0000
# Epoch:285,Loss:0.0000
# Epoch:286,Loss:0.0000
# Epoch:287,Loss:0.0000
# Epoch:288,Loss:0.0000
# Epoch:289,Loss:0.0000
# Epoch:290,Loss:0.0000
# Epoch:291,Loss:0.0000
# Epoch:292,Loss:0.0000
# Epoch:293,Loss:0.0001
# Epoch:294,Loss:0.0000
# Epoch:295,Loss:0.0002
# Epoch:296,Loss:0.0001
# Epoch:297,Loss:0.0000
# Epoch:298,Loss:0.0001
# Epoch:299,Loss:0.0000
# Epoch:300,Loss:0.0000
# Epoch:301,Loss:0.0000
# Epoch:302,Loss:0.0000
# Epoch:303,Loss:0.0000
# Epoch:304,Loss:0.0000
# Epoch:305,Loss:0.0000
# Epoch:306,Loss:0.0000
# Epoch:307,Loss:0.0000
# Epoch:308,Loss:0.0000
# Epoch:309,Loss:0.0000
# Epoch:310,Loss:0.0000
# Epoch:311,Loss:0.0000
# Epoch:312,Loss:0.0000
# Epoch:313,Loss:0.0000
# Epoch:314,Loss:0.0000
# Epoch:315,Loss:0.0000
# Epoch:316,Loss:0.0000
# Epoch:317,Loss:0.0000
# Epoch:318,Loss:0.0000
# Epoch:319,Loss:0.0000
# Epoch:320,Loss:0.0000
# Epoch:321,Loss:0.0000
# Epoch:322,Loss:0.0000
# Epoch:323,Loss:0.0000
# Epoch:324,Loss:0.0000
# Epoch:325,Loss:0.0000
# Epoch:326,Loss:0.0000
# Epoch:327,Loss:0.0000
# Epoch:328,Loss:0.0000
# Epoch:329,Loss:0.0000
# Epoch:330,Loss:0.0000
# Epoch:331,Loss:0.0000
# Epoch:332,Loss:0.0000
# Epoch:333,Loss:0.0000
# Epoch:334,Loss:0.0000
# Epoch:335,Loss:0.0000
# Epoch:336,Loss:0.0000
# Epoch:337,Loss:0.0000
# Epoch:338,Loss:0.0000
# Epoch:339,Loss:0.0000
# Epoch:340,Loss:0.0000
# Epoch:341,Loss:0.0000
# Epoch:342,Loss:0.0000
# Epoch:343,Loss:0.0000
# Epoch:344,Loss:0.0000
# Epoch:345,Loss:0.0000
# Epoch:346,Loss:0.0000
# Epoch:347,Loss:0.0000
# Epoch:348,Loss:0.0000
# Epoch:349,Loss:0.0000
# Epoch:350,Loss:0.0000
# Epoch:351,Loss:0.0000
# Epoch:352,Loss:0.0000
# Epoch:353,Loss:0.0000
# Epoch:354,Loss:0.0000
# Epoch:355,Loss:0.0000
# Epoch:356,Loss:0.0000
# Epoch:357,Loss:0.0000
# Epoch:358,Loss:0.0000
# Epoch:359,Loss:0.0000
# Epoch:360,Loss:0.0000
# Epoch:361,Loss:0.0000
# Epoch:362,Loss:0.0000
# Epoch:363,Loss:0.0000
# Epoch:364,Loss:0.0000
# Epoch:365,Loss:0.0000
# Epoch:366,Loss:0.0000
# Epoch:367,Loss:0.0000
# Epoch:368,Loss:0.0000
# Epoch:369,Loss:0.0000
# Epoch:370,Loss:0.0000
# Epoch:371,Loss:0.0000
# Epoch:372,Loss:0.0000
# Epoch:373,Loss:0.0000
# Epoch:374,Loss:0.0000
# Epoch:375,Loss:0.0001
# Epoch:376,Loss:0.0001
# Epoch:377,Loss:0.0001
# Epoch:378,Loss:0.0001
# Epoch:379,Loss:0.0002
# Epoch:380,Loss:0.0002
# Epoch:381,Loss:0.0002
# Epoch:382,Loss:0.0000
# Epoch:383,Loss:0.0174
# Epoch:384,Loss:0.0256
# Epoch:385,Loss:0.3289
# Epoch:386,Loss:0.2082
# Epoch:387,Loss:0.2061
# Epoch:388,Loss:0.2595
# Epoch:389,Loss:0.2225
# Epoch:390,Loss:0.2306
# Epoch:391,Loss:0.1519
# Epoch:392,Loss:0.1442
# Epoch:393,Loss:0.1445
# Epoch:394,Loss:0.0896
# Epoch:395,Loss:0.0698
# Epoch:396,Loss:0.0752
# Epoch:397,Loss:0.2366
# Epoch:398,Loss:0.0913
# Epoch:399,Loss:0.1194
# Epoch:400,Loss:0.0516
# Epoch:401,Loss:0.0374
# Epoch:402,Loss:0.0266
# Epoch:403,Loss:0.2288
# Epoch:404,Loss:0.0856
# Epoch:405,Loss:0.1025
# Epoch:406,Loss:0.0897
# Epoch:407,Loss:0.1756
# Epoch:408,Loss:0.0631
# Epoch:409,Loss:0.0765
# Epoch:410,Loss:0.0515
# Epoch:411,Loss:0.0500
# Epoch:412,Loss:0.0231
# Epoch:413,Loss:0.0117
# Epoch:414,Loss:0.0155
# Epoch:415,Loss:0.0088
# Epoch:416,Loss:0.0069
# Epoch:417,Loss:0.0046
# Epoch:418,Loss:0.0028
# Epoch:419,Loss:0.0022
# Epoch:420,Loss:0.0017
# Epoch:421,Loss:0.0014
# Epoch:422,Loss:0.0012
# Epoch:423,Loss:0.0009
# Epoch:424,Loss:0.0008
# Epoch:425,Loss:0.0006
# Epoch:426,Loss:0.0006
# Epoch:427,Loss:0.0004
# Epoch:428,Loss:0.0004
# Epoch:429,Loss:0.0003
# Epoch:430,Loss:0.0003
# Epoch:431,Loss:0.0002
# Epoch:432,Loss:0.0002
# Epoch:433,Loss:0.0002
# Epoch:434,Loss:0.0002
# Epoch:435,Loss:0.0002
# Epoch:436,Loss:0.0001
# Epoch:437,Loss:0.0001
# Epoch:438,Loss:0.0001
# Epoch:439,Loss:0.0001
# Epoch:440,Loss:0.0001
# Epoch:441,Loss:0.0001
# Epoch:442,Loss:0.0001
# Epoch:443,Loss:0.0001
# Epoch:444,Loss:0.0001
# Epoch:445,Loss:0.0001
# Epoch:446,Loss:0.0001
# Epoch:447,Loss:0.0001
# Epoch:448,Loss:0.0001
# Epoch:449,Loss:0.0000
# Epoch:450,Loss:0.0001
# Epoch:451,Loss:0.0001
# Epoch:452,Loss:0.0000
# Epoch:453,Loss:0.0000
# Epoch:454,Loss:0.0000
# Epoch:455,Loss:0.0000
# Epoch:456,Loss:0.0000
# Epoch:457,Loss:0.0000
# Epoch:458,Loss:0.0000
# Epoch:459,Loss:0.0000
# Epoch:460,Loss:0.0000
# Epoch:461,Loss:0.0000
# Epoch:462,Loss:0.0000
# Epoch:463,Loss:0.0000
# Epoch:464,Loss:0.0000
# Epoch:465,Loss:0.0000
# Epoch:466,Loss:0.0000
# Epoch:467,Loss:0.0000
# Epoch:468,Loss:0.0000
# Epoch:469,Loss:0.0000
# Epoch:470,Loss:0.0001
# Epoch:471,Loss:0.0000
# Epoch:472,Loss:0.0000
# Epoch:473,Loss:0.0000
# Epoch:474,Loss:0.0000
# Epoch:475,Loss:0.0000
# Epoch:476,Loss:0.0000
# Epoch:477,Loss:0.0000
# Epoch:478,Loss:0.0000
# Epoch:479,Loss:0.0000
# Epoch:480,Loss:0.0000
# Epoch:481,Loss:0.0000
# Epoch:482,Loss:0.0000
# Epoch:483,Loss:0.0000
# Epoch:484,Loss:0.0000
# Epoch:485,Loss:0.0000
# Epoch:486,Loss:0.0000
# Epoch:487,Loss:0.0000
# Epoch:488,Loss:0.0000
# Epoch:489,Loss:0.0000
# Epoch:490,Loss:0.0000
# Epoch:491,Loss:0.0000
# Epoch:492,Loss:0.0000
# Epoch:493,Loss:0.0000
# Epoch:494,Loss:0.0000
# Epoch:495,Loss:0.0000
# Epoch:496,Loss:0.0000
# Epoch:497,Loss:0.0000
# Epoch:498,Loss:0.0000
# Epoch:499,Loss:0.0000
# Epoch:500,Loss:0.0000
# erro =  0.6
# acerto =  0.4
# (80, 30)
# (80,)
# (10, 30)
# (10,)
# Input_Train torch.Size([8, 10, 30])
# Train_Labels torch.Size([8, 10, 1])
# Input_test torch.Size([1, 10, 30])
# test_Labels torch.Size([1, 10, 1])
# Epoch:1,Loss:0.2975
# Epoch:2,Loss:0.2045
# Epoch:3,Loss:0.2607
# Epoch:4,Loss:0.3065
# Epoch:5,Loss:0.2363
# Epoch:6,Loss:0.2284
# Epoch:7,Loss:0.1970
# Epoch:8,Loss:0.1755
# Epoch:9,Loss:0.1840
# Epoch:10,Loss:0.1912
# Epoch:11,Loss:0.1615
# Epoch:12,Loss:0.1469
# Epoch:13,Loss:0.1386
# Epoch:14,Loss:0.1220
# Epoch:15,Loss:0.1420
# Epoch:16,Loss:0.1237
# Epoch:17,Loss:0.2574
# Epoch:18,Loss:0.1296
# Epoch:19,Loss:0.1583
# Epoch:20,Loss:0.1550
# Epoch:21,Loss:0.1220
# Epoch:22,Loss:0.1252
# Epoch:23,Loss:0.1389
# Epoch:24,Loss:0.1079
# Epoch:25,Loss:0.1050
# Epoch:26,Loss:0.0953
# Epoch:27,Loss:0.1200
# Epoch:28,Loss:0.0928
# Epoch:29,Loss:0.1026
# Epoch:30,Loss:0.0899
# Epoch:31,Loss:0.1011
# Epoch:32,Loss:0.0886
# Epoch:33,Loss:0.0834
# Epoch:34,Loss:0.0856
# Epoch:35,Loss:0.0736
# Epoch:36,Loss:0.0702
# Epoch:37,Loss:0.0700
# Epoch:38,Loss:0.0744
# Epoch:39,Loss:0.0856
# Epoch:40,Loss:0.0611
# Epoch:41,Loss:0.0621
# Epoch:42,Loss:0.0571
# Epoch:43,Loss:0.0575
# Epoch:44,Loss:0.0541
# Epoch:45,Loss:0.0690
# Epoch:46,Loss:0.0654
# Epoch:47,Loss:0.0632
# Epoch:48,Loss:0.2013
# Epoch:49,Loss:0.0825
# Epoch:50,Loss:0.1062
# Epoch:51,Loss:0.0578
# Epoch:52,Loss:0.0654
# Epoch:53,Loss:0.0805
# Epoch:54,Loss:0.0851
# Epoch:55,Loss:0.0528
# Epoch:56,Loss:0.1081
# Epoch:57,Loss:0.0645
# Epoch:58,Loss:0.0811
# Epoch:59,Loss:0.0544
# Epoch:60,Loss:0.0534
# Epoch:61,Loss:0.0607
# Epoch:62,Loss:0.0371
# Epoch:63,Loss:0.0577
# Epoch:64,Loss:0.0481
# Epoch:65,Loss:0.0453
# Epoch:66,Loss:0.0947
# Epoch:67,Loss:0.0470
# Epoch:68,Loss:0.1084
# Epoch:69,Loss:0.2054
# Epoch:70,Loss:0.1917
# Epoch:71,Loss:0.1231
# Epoch:72,Loss:0.1332
# Epoch:73,Loss:0.0661
# Epoch:74,Loss:0.0266
# Epoch:75,Loss:0.0299
# Epoch:76,Loss:0.0303
# Epoch:77,Loss:0.0159
# Epoch:78,Loss:0.0210
# Epoch:79,Loss:0.0116
# Epoch:80,Loss:0.0120
# Epoch:81,Loss:0.0083
# Epoch:82,Loss:0.0072
# Epoch:83,Loss:0.0067
# Epoch:84,Loss:0.0054
# Epoch:85,Loss:0.0047
# Epoch:86,Loss:0.0041
# Epoch:87,Loss:0.0035
# Epoch:88,Loss:0.0030
# Epoch:89,Loss:0.0026
# Epoch:90,Loss:0.0023
# Epoch:91,Loss:0.0020
# Epoch:92,Loss:0.0017
# Epoch:93,Loss:0.0015
# Epoch:94,Loss:0.0013
# Epoch:95,Loss:0.0011
# Epoch:96,Loss:0.0010
# Epoch:97,Loss:0.0008
# Epoch:98,Loss:0.0008
# Epoch:99,Loss:0.0006
# Epoch:100,Loss:0.0006
# Epoch:101,Loss:0.0005
# Epoch:102,Loss:0.0005
# Epoch:103,Loss:0.0004
# Epoch:104,Loss:0.0004
# Epoch:105,Loss:0.0003
# Epoch:106,Loss:0.0003
# Epoch:107,Loss:0.0003
# Epoch:108,Loss:0.0003
# Epoch:109,Loss:0.0003
# Epoch:110,Loss:0.0003
# Epoch:111,Loss:0.0002
# Epoch:112,Loss:0.0002
# Epoch:113,Loss:0.0002
# Epoch:114,Loss:0.0002
# Epoch:115,Loss:0.0002
# Epoch:116,Loss:0.0002
# Epoch:117,Loss:0.0002
# Epoch:118,Loss:0.0002
# Epoch:119,Loss:0.0002
# Epoch:120,Loss:0.0002
# Epoch:121,Loss:0.0002
# Epoch:122,Loss:0.0002
# Epoch:123,Loss:0.0002
# Epoch:124,Loss:0.0001
# Epoch:125,Loss:0.0001
# Epoch:126,Loss:0.0001
# Epoch:127,Loss:0.0001
# Epoch:128,Loss:0.0001
# Epoch:129,Loss:0.0001
# Epoch:130,Loss:0.0001
# Epoch:131,Loss:0.0001
# Epoch:132,Loss:0.0001
# Epoch:133,Loss:0.0001
# Epoch:134,Loss:0.0001
# Epoch:135,Loss:0.0001
# Epoch:136,Loss:0.0001
# Epoch:137,Loss:0.0001
# Epoch:138,Loss:0.0001
# Epoch:139,Loss:0.0001
# Epoch:140,Loss:0.0001
# Epoch:141,Loss:0.0001
# Epoch:142,Loss:0.0001
# Epoch:143,Loss:0.0001
# Epoch:144,Loss:0.0001
# Epoch:145,Loss:0.0001
# Epoch:146,Loss:0.0001
# Epoch:147,Loss:0.0001
# Epoch:148,Loss:0.0001
# Epoch:149,Loss:0.0001
# Epoch:150,Loss:0.0001
# Epoch:151,Loss:0.0001
# Epoch:152,Loss:0.0001
# Epoch:153,Loss:0.0001
# Epoch:154,Loss:0.0001
# Epoch:155,Loss:0.0001
# Epoch:156,Loss:0.0001
# Epoch:157,Loss:0.0001
# Epoch:158,Loss:0.0001
# Epoch:159,Loss:0.0001
# Epoch:160,Loss:0.0001
# Epoch:161,Loss:0.0001
# Epoch:162,Loss:0.0001
# Epoch:163,Loss:0.0001
# Epoch:164,Loss:0.0000
# Epoch:165,Loss:0.0001
# Epoch:166,Loss:0.0001
# Epoch:167,Loss:0.0000
# Epoch:168,Loss:0.0001
# Epoch:169,Loss:0.0000
# Epoch:170,Loss:0.0000
# Epoch:171,Loss:0.0000
# Epoch:172,Loss:0.0000
# Epoch:173,Loss:0.0000
# Epoch:174,Loss:0.0000
# Epoch:175,Loss:0.0000
# Epoch:176,Loss:0.0000
# Epoch:177,Loss:0.0000
# Epoch:178,Loss:0.0000
# Epoch:179,Loss:0.0000
# Epoch:180,Loss:0.0000
# Epoch:181,Loss:0.0000
# Epoch:182,Loss:0.0000
# Epoch:183,Loss:0.0000
# Epoch:184,Loss:0.0000
# Epoch:185,Loss:0.0000
# Epoch:186,Loss:0.0000
# Epoch:187,Loss:0.0000
# Epoch:188,Loss:0.0000
# Epoch:189,Loss:0.0000
# Epoch:190,Loss:0.0000
# Epoch:191,Loss:0.0000
# Epoch:192,Loss:0.0000
# Epoch:193,Loss:0.0000
# Epoch:194,Loss:0.0000
# Epoch:195,Loss:0.0000
# Epoch:196,Loss:0.0000
# Epoch:197,Loss:0.0000
# Epoch:198,Loss:0.0000
# Epoch:199,Loss:0.0000
# Epoch:200,Loss:0.0000
# Epoch:201,Loss:0.0000
# Epoch:202,Loss:0.0000
# Epoch:203,Loss:0.0000
# Epoch:204,Loss:0.0000
# Epoch:205,Loss:0.0000
# Epoch:206,Loss:0.0000
# Epoch:207,Loss:0.0000
# Epoch:208,Loss:0.0000
# Epoch:209,Loss:0.0000
# Epoch:210,Loss:0.0000
# Epoch:211,Loss:0.0000
# Epoch:212,Loss:0.0000
# Epoch:213,Loss:0.0000
# Epoch:214,Loss:0.0000
# Epoch:215,Loss:0.0000
# Epoch:216,Loss:0.0000
# Epoch:217,Loss:0.0000
# Epoch:218,Loss:0.0000
# Epoch:219,Loss:0.0000
# Epoch:220,Loss:0.0000
# Epoch:221,Loss:0.0000
# Epoch:222,Loss:0.0000
# Epoch:223,Loss:0.0000
# Epoch:224,Loss:0.0000
# Epoch:225,Loss:0.0000
# Epoch:226,Loss:0.0000
# Epoch:227,Loss:0.0000
# Epoch:228,Loss:0.0000
# Epoch:229,Loss:0.0000
# Epoch:230,Loss:0.0000
# Epoch:231,Loss:0.0000
# Epoch:232,Loss:0.0000
# Epoch:233,Loss:0.0001
# Epoch:234,Loss:0.0000
# Epoch:235,Loss:0.0001
# Epoch:236,Loss:0.0000
# Epoch:237,Loss:0.0001
# Epoch:238,Loss:0.0000
# Epoch:239,Loss:0.0000
# Epoch:240,Loss:0.0001
# Epoch:241,Loss:0.0000
# Epoch:242,Loss:0.0001
# Epoch:243,Loss:0.0000
# Epoch:244,Loss:0.0001
# Epoch:245,Loss:0.0000
# Epoch:246,Loss:0.0001
# Epoch:247,Loss:0.0001
# Epoch:248,Loss:0.0000
# Epoch:249,Loss:0.0001
# Epoch:250,Loss:0.0000
# Epoch:251,Loss:0.0001
# Epoch:252,Loss:0.0000
# Epoch:253,Loss:0.0001
# Epoch:254,Loss:0.0000
# Epoch:255,Loss:0.0000
# Epoch:256,Loss:0.0001
# Epoch:257,Loss:0.0000
# Epoch:258,Loss:0.0001
# Epoch:259,Loss:0.0000
# Epoch:260,Loss:0.0000
# Epoch:261,Loss:0.0000
# Epoch:262,Loss:0.0000
# Epoch:263,Loss:0.0000
# Epoch:264,Loss:0.0000
# Epoch:265,Loss:0.0000
# Epoch:266,Loss:0.0000
# Epoch:267,Loss:0.0000
# Epoch:268,Loss:0.0000
# Epoch:269,Loss:0.0000
# Epoch:270,Loss:0.0000
# Epoch:271,Loss:0.0000
# Epoch:272,Loss:0.0000
# Epoch:273,Loss:0.0000
# Epoch:274,Loss:0.0000
# Epoch:275,Loss:0.0000
# Epoch:276,Loss:0.0000
# Epoch:277,Loss:0.0000
# Epoch:278,Loss:0.0001
# Epoch:279,Loss:0.0000
# Epoch:280,Loss:0.0001
# Epoch:281,Loss:0.0000
# Epoch:282,Loss:0.0001
# Epoch:283,Loss:0.0001
# Epoch:284,Loss:0.0000
# Epoch:285,Loss:0.0002
# Epoch:286,Loss:0.0000
# Epoch:287,Loss:0.0002
# Epoch:288,Loss:0.0001
# Epoch:289,Loss:0.0003
# Epoch:290,Loss:0.0001
# Epoch:291,Loss:0.0003
# Epoch:292,Loss:0.0003
# Epoch:293,Loss:0.0001
# Epoch:294,Loss:0.0004
# Epoch:295,Loss:0.0001
# Epoch:296,Loss:0.0002
# Epoch:297,Loss:0.0001
# Epoch:298,Loss:0.0001
# Epoch:299,Loss:0.0001
# Epoch:300,Loss:0.0000
# Epoch:301,Loss:0.0000
# Epoch:302,Loss:0.0000
# Epoch:303,Loss:0.0000
# Epoch:304,Loss:0.0000
# Epoch:305,Loss:0.0000
# Epoch:306,Loss:0.0000
# Epoch:307,Loss:0.0000
# Epoch:308,Loss:0.0000
# Epoch:309,Loss:0.0000
# Epoch:310,Loss:0.0000
# Epoch:311,Loss:0.0000
# Epoch:312,Loss:0.0000
# Epoch:313,Loss:0.0000
# Epoch:314,Loss:0.0000
# Epoch:315,Loss:0.0000
# Epoch:316,Loss:0.0000
# Epoch:317,Loss:0.0000
# Epoch:318,Loss:0.0000
# Epoch:319,Loss:0.0000
# Epoch:320,Loss:0.0000
# Epoch:321,Loss:0.0000
# Epoch:322,Loss:0.0000
# Epoch:323,Loss:0.0000
# Epoch:324,Loss:0.0000
# Epoch:325,Loss:0.0000
# Epoch:326,Loss:0.0000
# Epoch:327,Loss:0.0000
# Epoch:328,Loss:0.0000
# Epoch:329,Loss:0.0000
# Epoch:330,Loss:0.0000
# Epoch:331,Loss:0.0000
# Epoch:332,Loss:0.0000
# Epoch:333,Loss:0.0000
# Epoch:334,Loss:0.0000
# Epoch:335,Loss:0.0000
# Epoch:336,Loss:0.0000
# Epoch:337,Loss:0.0000
# Epoch:338,Loss:0.0000
# Epoch:339,Loss:0.0000
# Epoch:340,Loss:0.0000
# Epoch:341,Loss:0.0000
# Epoch:342,Loss:0.0000
# Epoch:343,Loss:0.0000
# Epoch:344,Loss:0.0000
# Epoch:345,Loss:0.0000
# Epoch:346,Loss:0.0000
# Epoch:347,Loss:0.0000
# Epoch:348,Loss:0.0000
# Epoch:349,Loss:0.0000
# Epoch:350,Loss:0.0000
# Epoch:351,Loss:0.0001
# Epoch:352,Loss:0.0000
# Epoch:353,Loss:0.0001
# Epoch:354,Loss:0.0001
# Epoch:355,Loss:0.0002
# Epoch:356,Loss:0.0001
# Epoch:357,Loss:0.0004
# Epoch:358,Loss:0.0007
# Epoch:359,Loss:0.0003
# Epoch:360,Loss:0.0011
# Epoch:361,Loss:0.0005
# Epoch:362,Loss:0.0028
# Epoch:363,Loss:0.0014
# Epoch:364,Loss:0.0010
# Epoch:365,Loss:0.0017
# Epoch:366,Loss:0.0010
# Epoch:367,Loss:0.0004
# Epoch:368,Loss:0.0003
# Epoch:369,Loss:0.0000
# Epoch:370,Loss:0.0004
# Epoch:371,Loss:0.0002
# Epoch:372,Loss:0.0001
# Epoch:373,Loss:0.0000
# Epoch:374,Loss:0.0000
# Epoch:375,Loss:0.0000
# Epoch:376,Loss:0.0000
# Epoch:377,Loss:0.0000
# Epoch:378,Loss:0.0000
# Epoch:379,Loss:0.0000
# Epoch:380,Loss:0.0000
# Epoch:381,Loss:0.0000
# Epoch:382,Loss:0.0000
# Epoch:383,Loss:0.0000
# Epoch:384,Loss:0.0000
# Epoch:385,Loss:0.0000
# Epoch:386,Loss:0.0000
# Epoch:387,Loss:0.0000
# Epoch:388,Loss:0.0000
# Epoch:389,Loss:0.0000
# Epoch:390,Loss:0.0000
# Epoch:391,Loss:0.0000
# Epoch:392,Loss:0.0000
# Epoch:393,Loss:0.0000
# Epoch:394,Loss:0.0000
# Epoch:395,Loss:0.0000
# Epoch:396,Loss:0.0000
# Epoch:397,Loss:0.0000
# Epoch:398,Loss:0.0000
# Epoch:399,Loss:0.0000
# Epoch:400,Loss:0.0000
# Epoch:401,Loss:0.0000
# Epoch:402,Loss:0.0000
# Epoch:403,Loss:0.0000
# Epoch:404,Loss:0.0000
# Epoch:405,Loss:0.0000
# Epoch:406,Loss:0.0000
# Epoch:407,Loss:0.0000
# Epoch:408,Loss:0.0000
# Epoch:409,Loss:0.0000
# Epoch:410,Loss:0.0000
# Epoch:411,Loss:0.0000
# Epoch:412,Loss:0.0000
# Epoch:413,Loss:0.0000
# Epoch:414,Loss:0.0000
# Epoch:415,Loss:0.0000
# Epoch:416,Loss:0.0000
# Epoch:417,Loss:0.0000
# Epoch:418,Loss:0.0000
# Epoch:419,Loss:0.0000
# Epoch:420,Loss:0.0000
# Epoch:421,Loss:0.0000
# Epoch:422,Loss:0.0000
# Epoch:423,Loss:0.0000
# Epoch:424,Loss:0.0000
# Epoch:425,Loss:0.0000
# Epoch:426,Loss:0.0000
# Epoch:427,Loss:0.0000
# Epoch:428,Loss:0.0000
# Epoch:429,Loss:0.0000
# Epoch:430,Loss:0.0000
# Epoch:431,Loss:0.0000
# Epoch:432,Loss:0.0000
# Epoch:433,Loss:0.0000
# Epoch:434,Loss:0.0000
# Epoch:435,Loss:0.0000
# Epoch:436,Loss:0.0000
# Epoch:437,Loss:0.0000
# Epoch:438,Loss:0.0000
# Epoch:439,Loss:0.0000
# Epoch:440,Loss:0.0000
# Epoch:441,Loss:0.0000
# Epoch:442,Loss:0.0000
# Epoch:443,Loss:0.0000
# Epoch:444,Loss:0.0000
# Epoch:445,Loss:0.0000
# Epoch:446,Loss:0.0000
# Epoch:447,Loss:0.0000
# Epoch:448,Loss:0.0000
# Epoch:449,Loss:0.0000
# Epoch:450,Loss:0.0000
# Epoch:451,Loss:0.0000
# Epoch:452,Loss:0.0000
# Epoch:453,Loss:0.0000
# Epoch:454,Loss:0.0000
# Epoch:455,Loss:0.0000
# Epoch:456,Loss:0.0000
# Epoch:457,Loss:0.0001
# Epoch:458,Loss:0.0000
# Epoch:459,Loss:0.0001
# Epoch:460,Loss:0.0000
# Epoch:461,Loss:0.0004
# Epoch:462,Loss:0.0001
# Epoch:463,Loss:0.0006
# Epoch:464,Loss:0.0003
# Epoch:465,Loss:0.0011
# Epoch:466,Loss:0.0005
# Epoch:467,Loss:0.0010
# Epoch:468,Loss:0.0011
# Epoch:469,Loss:0.0018
# Epoch:470,Loss:0.0011
# Epoch:471,Loss:0.0002
# Epoch:472,Loss:0.0009
# Epoch:473,Loss:0.0002
# Epoch:474,Loss:0.0001
# Epoch:475,Loss:0.0000
# Epoch:476,Loss:0.0000
# Epoch:477,Loss:0.0000
# Epoch:478,Loss:0.0000
# Epoch:479,Loss:0.0000
# Epoch:480,Loss:0.0000
# Epoch:481,Loss:0.0000
# Epoch:482,Loss:0.0000
# Epoch:483,Loss:0.0000
# Epoch:484,Loss:0.0000
# Epoch:485,Loss:0.0000
# Epoch:486,Loss:0.0000
# Epoch:487,Loss:0.0000
# Epoch:488,Loss:0.0000
# Epoch:489,Loss:0.0000
# Epoch:490,Loss:0.0000
# Epoch:491,Loss:0.0000
# Epoch:492,Loss:0.0000
# Epoch:493,Loss:0.0000
# Epoch:494,Loss:0.0000
# Epoch:495,Loss:0.0000
# Epoch:496,Loss:0.0000
# Epoch:497,Loss:0.0000
# Epoch:498,Loss:0.0000
# Epoch:499,Loss:0.0000
# Epoch:500,Loss:0.0000
# erro =  0.6
# acerto =  0.4

# %% [markdown]
# * Label = 0 (primeira parte do gráfico)
# * Label = 1 (segunda parte do gráfico)
# * Se a resposta for 0 quer dizer que a rede acha que o gráfico que foi apresentado é um gráfico do inicio.
# * Se a resposta for 1, a rede acha que é da segunda parte.

# %% [markdown]
# * __Small data neural networks__
#
# https://www.ictp.it/about-ictp/media-centre/news/2021/11/tinyml.aspx#close
# * __calcular a porcentagem de erro__
#
# * __separar o dataset em 1/4 de inicio e 1/4 de  final.__

# %%
eval_model(200)
# Out:
# (10, 30)
# (10,)
# (80, 30)
# (80,)
# Input_Train torch.Size([1, 10, 30])
# Train_Labels torch.Size([1, 10, 1])
# Input_test torch.Size([8, 10, 30])
# test_Labels torch.Size([8, 10, 1])
# Epoch:1,Loss:0.0000
# Epoch:2,Loss:0.0000
# Epoch:3,Loss:0.0000
# Epoch:4,Loss:0.0000
# Epoch:5,Loss:0.0000
# Epoch:6,Loss:0.0000
# Epoch:7,Loss:0.0000
# Epoch:8,Loss:0.0000
# Epoch:9,Loss:0.0000
# Epoch:10,Loss:0.0000
# Epoch:11,Loss:0.0000
# Epoch:12,Loss:0.0000
# Epoch:13,Loss:0.0000
# Epoch:14,Loss:0.0000
# Epoch:15,Loss:0.0000
# Epoch:16,Loss:0.0000
# Epoch:17,Loss:0.0000
# Epoch:18,Loss:0.0000
# Epoch:19,Loss:0.0000
# Epoch:20,Loss:0.0000
# Epoch:21,Loss:0.0000
# Epoch:22,Loss:0.0000
# Epoch:23,Loss:0.0000
# Epoch:24,Loss:0.0000
# Epoch:25,Loss:0.0000
# Epoch:26,Loss:0.0000
# Epoch:27,Loss:0.0000
# Epoch:28,Loss:0.0000
# Epoch:29,Loss:0.0000
# Epoch:30,Loss:0.0000
# Epoch:31,Loss:0.0000
# Epoch:32,Loss:0.0000
# Epoch:33,Loss:0.0000
# Epoch:34,Loss:0.0000
# Epoch:35,Loss:0.0000
# Epoch:36,Loss:0.0000
# Epoch:37,Loss:0.0000
# Epoch:38,Loss:0.0000
# Epoch:39,Loss:0.0000
# Epoch:40,Loss:0.0000
# Epoch:41,Loss:0.0000
# Epoch:42,Loss:0.0000
# Epoch:43,Loss:0.0000
# Epoch:44,Loss:0.0000
# Epoch:45,Loss:0.0000
# Epoch:46,Loss:0.0000
# Epoch:47,Loss:0.0000
# Epoch:48,Loss:0.0000
# Epoch:49,Loss:0.0000
# Epoch:50,Loss:0.0000
# Epoch:51,Loss:0.0000
# Epoch:52,Loss:0.0000
# Epoch:53,Loss:0.0000
# Epoch:54,Loss:0.0000
# Epoch:55,Loss:0.0000
# Epoch:56,Loss:0.0000
# Epoch:57,Loss:0.0000
# Epoch:58,Loss:0.0000
# Epoch:59,Loss:0.0000
# Epoch:60,Loss:0.0000
# Epoch:61,Loss:0.0000
# Epoch:62,Loss:0.0000
# Epoch:63,Loss:0.0000
# Epoch:64,Loss:0.0000
# Epoch:65,Loss:0.0000
# Epoch:66,Loss:0.0000
# Epoch:67,Loss:0.0000
# Epoch:68,Loss:0.0000
# Epoch:69,Loss:0.0000
# Epoch:70,Loss:0.0000
# Epoch:71,Loss:0.0000
# Epoch:72,Loss:0.0000
# Epoch:73,Loss:0.0000
# Epoch:74,Loss:0.0000
# Epoch:75,Loss:0.0000
# Epoch:76,Loss:0.0000
# Epoch:77,Loss:0.0000
# Epoch:78,Loss:0.0000
# Epoch:79,Loss:0.0000
# Epoch:80,Loss:0.0000
# Epoch:81,Loss:0.0000
# Epoch:82,Loss:0.0000
# Epoch:83,Loss:0.0000
# Epoch:84,Loss:0.0000
# Epoch:85,Loss:0.0000
# Epoch:86,Loss:0.0000
# Epoch:87,Loss:0.0000
# Epoch:88,Loss:0.0000
# Epoch:89,Loss:0.0000
# Epoch:90,Loss:0.0000
# Epoch:91,Loss:0.0000
# Epoch:92,Loss:0.0000
# Epoch:93,Loss:0.0000
# Epoch:94,Loss:0.0000
# Epoch:95,Loss:0.0000
# Epoch:96,Loss:0.0000
# Epoch:97,Loss:0.0000
# Epoch:98,Loss:0.0000
# Epoch:99,Loss:0.0000
# Epoch:100,Loss:0.0000
# Epoch:101,Loss:0.0000
# Epoch:102,Loss:0.0000
# Epoch:103,Loss:0.0000
# Epoch:104,Loss:0.0000
# Epoch:105,Loss:0.0000
# Epoch:106,Loss:0.0000
# Epoch:107,Loss:0.0000
# Epoch:108,Loss:0.0000
# Epoch:109,Loss:0.0000
# Epoch:110,Loss:0.0000
# Epoch:111,Loss:0.0000
# Epoch:112,Loss:0.0000
# Epoch:113,Loss:0.0000
# Epoch:114,Loss:0.0000
# Epoch:115,Loss:0.0000
# Epoch:116,Loss:0.0000
# Epoch:117,Loss:0.0000
# Epoch:118,Loss:0.0000
# Epoch:119,Loss:0.0000
# Epoch:120,Loss:0.0000
# Epoch:121,Loss:0.0000
# Epoch:122,Loss:0.0000
# Epoch:123,Loss:0.0000
# Epoch:124,Loss:0.0000
# Epoch:125,Loss:0.0000
# Epoch:126,Loss:0.0000
# Epoch:127,Loss:0.0000
# Epoch:128,Loss:0.0000
# Epoch:129,Loss:0.0000
# Epoch:130,Loss:0.0000
# Epoch:131,Loss:0.0000
# Epoch:132,Loss:0.0000
# Epoch:133,Loss:0.0000
# Epoch:134,Loss:0.0000
# Epoch:135,Loss:0.0000
# Epoch:136,Loss:0.0000
# Epoch:137,Loss:0.0000
# Epoch:138,Loss:0.0000
# Epoch:139,Loss:0.0000
# Epoch:140,Loss:0.0000
# Epoch:141,Loss:0.0000
# Epoch:142,Loss:0.0000
# Epoch:143,Loss:0.0000
# Epoch:144,Loss:0.0000
# Epoch:145,Loss:0.0000
# Epoch:146,Loss:0.0000
# Epoch:147,Loss:0.0000
# Epoch:148,Loss:0.0000
# Epoch:149,Loss:0.0000
# Epoch:150,Loss:0.0000
# Epoch:151,Loss:0.0000
# Epoch:152,Loss:0.0000
# Epoch:153,Loss:0.0000
# Epoch:154,Loss:0.0000
# Epoch:155,Loss:0.0000
# Epoch:156,Loss:0.0000
# Epoch:157,Loss:0.0000
# Epoch:158,Loss:0.0000
# Epoch:159,Loss:0.0000
# Epoch:160,Loss:0.0000
# Epoch:161,Loss:0.0000
# Epoch:162,Loss:0.0000
# Epoch:163,Loss:0.0000
# Epoch:164,Loss:0.0000
# Epoch:165,Loss:0.0000
# Epoch:166,Loss:0.0000
# Epoch:167,Loss:0.0000
# Epoch:168,Loss:0.0000
# Epoch:169,Loss:0.0000
# Epoch:170,Loss:0.0000
# Epoch:171,Loss:0.0000
# Epoch:172,Loss:0.0000
# Epoch:173,Loss:0.0000
# Epoch:174,Loss:0.0000
# Epoch:175,Loss:0.0000
# Epoch:176,Loss:0.0000
# Epoch:177,Loss:0.0000
# Epoch:178,Loss:0.0000
# Epoch:179,Loss:0.0000
# Epoch:180,Loss:0.0000
# Epoch:181,Loss:0.0000
# Epoch:182,Loss:0.0000
# Epoch:183,Loss:0.0000
# Epoch:184,Loss:0.0000
# Epoch:185,Loss:0.0000
# Epoch:186,Loss:0.0000
# Epoch:187,Loss:0.0000
# Epoch:188,Loss:0.0000
# Epoch:189,Loss:0.0000
# Epoch:190,Loss:0.0000
# Epoch:191,Loss:0.0000
# Epoch:192,Loss:0.0000
# Epoch:193,Loss:0.0000
# Epoch:194,Loss:0.0000
# Epoch:195,Loss:0.0000
# Epoch:196,Loss:0.0000
# Epoch:197,Loss:0.0000
# Epoch:198,Loss:0.0000
# Epoch:199,Loss:0.0000
# Epoch:200,Loss:0.0000
# erro =  0.6
# acerto =  0.4
# (20, 30)
# (20,)
# (70, 30)
# (70,)
# Input_Train torch.Size([2, 10, 30])
# Train_Labels torch.Size([2, 10, 1])
# Input_test torch.Size([7, 10, 30])
# test_Labels torch.Size([7, 10, 1])
# Epoch:1,Loss:0.0000
# Epoch:2,Loss:0.0000
# Epoch:3,Loss:0.0000
# Epoch:4,Loss:0.0000
# Epoch:5,Loss:0.0000
# Epoch:6,Loss:0.0000
# Epoch:7,Loss:0.0000
# Epoch:8,Loss:0.0000
# Epoch:9,Loss:0.0000
# Epoch:10,Loss:0.0000
# Epoch:11,Loss:0.0000
# Epoch:12,Loss:0.0000
# Epoch:13,Loss:0.0000
# Epoch:14,Loss:0.0000
# Epoch:15,Loss:0.0000
# Epoch:16,Loss:0.0000
# Epoch:17,Loss:0.0000
# Epoch:18,Loss:0.0000
# Epoch:19,Loss:0.0000
# Epoch:20,Loss:0.0000
# Epoch:21,Loss:0.0000
# Epoch:22,Loss:0.0000
# Epoch:23,Loss:0.0000
# Epoch:24,Loss:0.0000
# Epoch:25,Loss:0.0000
# Epoch:26,Loss:0.0000
# Epoch:27,Loss:0.0000
# Epoch:28,Loss:0.0000
# Epoch:29,Loss:0.0000
# Epoch:30,Loss:0.0000
# Epoch:31,Loss:0.0000
# Epoch:32,Loss:0.0000
# Epoch:33,Loss:0.0000
# Epoch:34,Loss:0.0000
# Epoch:35,Loss:0.0000
# Epoch:36,Loss:0.0000
# Epoch:37,Loss:0.0000
# Epoch:38,Loss:0.0000
# Epoch:39,Loss:0.0000
# Epoch:40,Loss:0.0000
# Epoch:41,Loss:0.0000
# Epoch:42,Loss:0.0000
# Epoch:43,Loss:0.0000
# Epoch:44,Loss:0.0000
# Epoch:45,Loss:0.0000
# Epoch:46,Loss:0.0000
# Epoch:47,Loss:0.0000
# Epoch:48,Loss:0.0000
# Epoch:49,Loss:0.0000
# Epoch:50,Loss:0.0000
# Epoch:51,Loss:0.0000
# Epoch:52,Loss:0.0000
# Epoch:53,Loss:0.0000
# Epoch:54,Loss:0.0000
# Epoch:55,Loss:0.0000
# Epoch:56,Loss:0.0000
# Epoch:57,Loss:0.0000
# Epoch:58,Loss:0.0000
# Epoch:59,Loss:0.0000
# Epoch:60,Loss:0.0000
# Epoch:61,Loss:0.0000
# Epoch:62,Loss:0.0000
# Epoch:63,Loss:0.0000
# Epoch:64,Loss:0.0000
# Epoch:65,Loss:0.0000
# Epoch:66,Loss:0.0000
# Epoch:67,Loss:0.0000
# Epoch:68,Loss:0.0000
# Epoch:69,Loss:0.0000
# Epoch:70,Loss:0.0000
# Epoch:71,Loss:0.0000
# Epoch:72,Loss:0.0000
# Epoch:73,Loss:0.0000
# Epoch:74,Loss:0.0000
# Epoch:75,Loss:0.0000
# Epoch:76,Loss:0.0000
# Epoch:77,Loss:0.0000
# Epoch:78,Loss:0.0000
# Epoch:79,Loss:0.0000
# Epoch:80,Loss:0.0000
# Epoch:81,Loss:0.0000
# Epoch:82,Loss:0.0000
# Epoch:83,Loss:0.0000
# Epoch:84,Loss:0.0000
# Epoch:85,Loss:0.0000
# Epoch:86,Loss:0.0000
# Epoch:87,Loss:0.0000
# Epoch:88,Loss:0.0000
# Epoch:89,Loss:0.0000
# Epoch:90,Loss:0.0000
# Epoch:91,Loss:0.0000
# Epoch:92,Loss:0.0000
# Epoch:93,Loss:0.0000
# Epoch:94,Loss:0.0000
# Epoch:95,Loss:0.0000
# Epoch:96,Loss:0.0000
# Epoch:97,Loss:0.0000
# Epoch:98,Loss:0.0000
# Epoch:99,Loss:0.0000
# Epoch:100,Loss:0.0000
# Epoch:101,Loss:0.0000
# Epoch:102,Loss:0.0000
# Epoch:103,Loss:0.0000
# Epoch:104,Loss:0.0000
# Epoch:105,Loss:0.0000
# Epoch:106,Loss:0.0000
# Epoch:107,Loss:0.0000
# Epoch:108,Loss:0.0000
# Epoch:109,Loss:0.0000
# Epoch:110,Loss:0.0000
# Epoch:111,Loss:0.0000
# Epoch:112,Loss:0.0000
# Epoch:113,Loss:0.0000
# Epoch:114,Loss:0.0000
# Epoch:115,Loss:0.0000
# Epoch:116,Loss:0.0000
# Epoch:117,Loss:0.0000
# Epoch:118,Loss:0.0000
# Epoch:119,Loss:0.0000
# Epoch:120,Loss:0.0000
# Epoch:121,Loss:0.0000
# Epoch:122,Loss:0.0000
# Epoch:123,Loss:0.0000
# Epoch:124,Loss:0.0000
# Epoch:125,Loss:0.0000
# Epoch:126,Loss:0.0000
# Epoch:127,Loss:0.0000
# Epoch:128,Loss:0.0000
# Epoch:129,Loss:0.0000
# Epoch:130,Loss:0.0000
# Epoch:131,Loss:0.0000
# Epoch:132,Loss:0.0000
# Epoch:133,Loss:0.0000
# Epoch:134,Loss:0.0000
# Epoch:135,Loss:0.0000
# Epoch:136,Loss:0.0000
# Epoch:137,Loss:0.0000
# Epoch:138,Loss:0.0000
# Epoch:139,Loss:0.0000
# Epoch:140,Loss:0.0000
# Epoch:141,Loss:0.0000
# Epoch:142,Loss:0.0000
# Epoch:143,Loss:0.0000
# Epoch:144,Loss:0.0000
# Epoch:145,Loss:0.0000
# Epoch:146,Loss:0.0000
# Epoch:147,Loss:0.0000
# Epoch:148,Loss:0.0000
# Epoch:149,Loss:0.0000
# Epoch:150,Loss:0.0000
# Epoch:151,Loss:0.0000
# Epoch:152,Loss:0.0000
# Epoch:153,Loss:0.0000
# Epoch:154,Loss:0.0000
# Epoch:155,Loss:0.0000
# Epoch:156,Loss:0.0000
# Epoch:157,Loss:0.0000
# Epoch:158,Loss:0.0000
# Epoch:159,Loss:0.0000
# Epoch:160,Loss:0.0000
# Epoch:161,Loss:0.0000
# Epoch:162,Loss:0.0000
# Epoch:163,Loss:0.0000
# Epoch:164,Loss:0.0000
# Epoch:165,Loss:0.0000
# Epoch:166,Loss:0.0000
# Epoch:167,Loss:0.0000
# Epoch:168,Loss:0.0000
# Epoch:169,Loss:0.0000
# Epoch:170,Loss:0.0000
# Epoch:171,Loss:0.0000
# Epoch:172,Loss:0.0000
# Epoch:173,Loss:0.0000
# Epoch:174,Loss:0.0000
# Epoch:175,Loss:0.0000
# Epoch:176,Loss:0.0000
# Epoch:177,Loss:0.0000
# Epoch:178,Loss:0.0000
# Epoch:179,Loss:0.0000
# Epoch:180,Loss:0.0000
# Epoch:181,Loss:0.0000
# Epoch:182,Loss:0.0000
# Epoch:183,Loss:0.0000
# Epoch:184,Loss:0.0000
# Epoch:185,Loss:0.0000
# Epoch:186,Loss:0.0000
# Epoch:187,Loss:0.0000
# Epoch:188,Loss:0.0000
# Epoch:189,Loss:0.0000
# Epoch:190,Loss:0.0000
# Epoch:191,Loss:0.0000
# Epoch:192,Loss:0.0000
# Epoch:193,Loss:0.0000
# Epoch:194,Loss:0.0000
# Epoch:195,Loss:0.0000
# Epoch:196,Loss:0.0000
# Epoch:197,Loss:0.0000
# Epoch:198,Loss:0.0000
# Epoch:199,Loss:0.0000
# Epoch:200,Loss:0.0000
# erro =  0.6857142857142857
# acerto =  0.3142857142857143
# (30, 30)
# (30,)
# (60, 30)
# (60,)
# Input_Train torch.Size([3, 10, 30])
# Train_Labels torch.Size([3, 10, 1])
# Input_test torch.Size([6, 10, 30])
# test_Labels torch.Size([6, 10, 1])
# Epoch:1,Loss:0.0001
# Epoch:2,Loss:0.0000
# Epoch:3,Loss:0.0000
# Epoch:4,Loss:0.0000
# Epoch:5,Loss:0.0000
# Epoch:6,Loss:0.0000
# Epoch:7,Loss:0.0000
# Epoch:8,Loss:0.0000
# Epoch:9,Loss:0.0000
# Epoch:10,Loss:0.0000
# Epoch:11,Loss:0.0000
# Epoch:12,Loss:0.0000
# Epoch:13,Loss:0.0000
# Epoch:14,Loss:0.0000
# Epoch:15,Loss:0.0000
# Epoch:16,Loss:0.0000
# Epoch:17,Loss:0.0000
# Epoch:18,Loss:0.0000
# Epoch:19,Loss:0.0000
# Epoch:20,Loss:0.0000
# Epoch:21,Loss:0.0000
# Epoch:22,Loss:0.0000
# Epoch:23,Loss:0.0000
# Epoch:24,Loss:0.0000
# Epoch:25,Loss:0.0000
# Epoch:26,Loss:0.0000
# Epoch:27,Loss:0.0000
# Epoch:28,Loss:0.0000
# Epoch:29,Loss:0.0000
# Epoch:30,Loss:0.0000
# Epoch:31,Loss:0.0000
# Epoch:32,Loss:0.0000
# Epoch:33,Loss:0.0000
# Epoch:34,Loss:0.0000
# Epoch:35,Loss:0.0000
# Epoch:36,Loss:0.0000
# Epoch:37,Loss:0.0000
# Epoch:38,Loss:0.0000
# Epoch:39,Loss:0.0000
# Epoch:40,Loss:0.0000
# Epoch:41,Loss:0.0000
# Epoch:42,Loss:0.0000
# Epoch:43,Loss:0.0000
# Epoch:44,Loss:0.0000
# Epoch:45,Loss:0.0000
# Epoch:46,Loss:0.0000
# Epoch:47,Loss:0.0000
# Epoch:48,Loss:0.0000
# Epoch:49,Loss:0.0000
# Epoch:50,Loss:0.0000
# Epoch:51,Loss:0.0000
# Epoch:52,Loss:0.0000
# Epoch:53,Loss:0.0000
# Epoch:54,Loss:0.0000
# Epoch:55,Loss:0.0000
# Epoch:56,Loss:0.0000
# Epoch:57,Loss:0.0000
# Epoch:58,Loss:0.0000
# Epoch:59,Loss:0.0000
# Epoch:60,Loss:0.0000
# Epoch:61,Loss:0.0000
# Epoch:62,Loss:0.0000
# Epoch:63,Loss:0.0000
# Epoch:64,Loss:0.0000
# Epoch:65,Loss:0.0000
# Epoch:66,Loss:0.0000
# Epoch:67,Loss:0.0000
# Epoch:68,Loss:0.0000
# Epoch:69,Loss:0.0000
# Epoch:70,Loss:0.0000
# Epoch:71,Loss:0.0000
# Epoch:72,Loss:0.0000
# Epoch:73,Loss:0.0000
# Epoch:74,Loss:0.0000
# Epoch:75,Loss:0.0000
# Epoch:76,Loss:0.0000
# Epoch:77,Loss:0.0000
# Epoch:78,Loss:0.0000
# Epoch:79,Loss:0.0000
# Epoch:80,Loss:0.0000
# Epoch:81,Loss:0.0000
# Epoch:82,Loss:0.0000
# Epoch:83,Loss:0.0000
# Epoch:84,Loss:0.0000
# Epoch:85,Loss:0.0000
# Epoch:86,Loss:0.0000
# Epoch:87,Loss:0.0000
# Epoch:88,Loss:0.0000
# Epoch:89,Loss:0.0000
# Epoch:90,Loss:0.0000
# Epoch:91,Loss:0.0000
# Epoch:92,Loss:0.0000
# Epoch:93,Loss:0.0000
# Epoch:94,Loss:0.0000
# Epoch:95,Loss:0.0000
# Epoch:96,Loss:0.0000
# Epoch:97,Loss:0.0000
# Epoch:98,Loss:0.0000
# Epoch:99,Loss:0.0000
# Epoch:100,Loss:0.0000
# Epoch:101,Loss:0.0000
# Epoch:102,Loss:0.0000
# Epoch:103,Loss:0.0000
# Epoch:104,Loss:0.0000
# Epoch:105,Loss:0.0000
# Epoch:106,Loss:0.0000
# Epoch:107,Loss:0.0000
# Epoch:108,Loss:0.0000
# Epoch:109,Loss:0.0000
# Epoch:110,Loss:0.0000
# Epoch:111,Loss:0.0000
# Epoch:112,Loss:0.0000
# Epoch:113,Loss:0.0000
# Epoch:114,Loss:0.0000
# Epoch:115,Loss:0.0000
# Epoch:116,Loss:0.0000
# Epoch:117,Loss:0.0000
# Epoch:118,Loss:0.0000
# Epoch:119,Loss:0.0000
# Epoch:120,Loss:0.0000
# Epoch:121,Loss:0.0000
# Epoch:122,Loss:0.0000
# Epoch:123,Loss:0.0000
# Epoch:124,Loss:0.0000
# Epoch:125,Loss:0.0000
# Epoch:126,Loss:0.0000
# Epoch:127,Loss:0.0000
# Epoch:128,Loss:0.0000
# Epoch:129,Loss:0.0000
# Epoch:130,Loss:0.0000
# Epoch:131,Loss:0.0000
# Epoch:132,Loss:0.0000
# Epoch:133,Loss:0.0000
# Epoch:134,Loss:0.0000
# Epoch:135,Loss:0.0000
# Epoch:136,Loss:0.0000
# Epoch:137,Loss:0.0000
# Epoch:138,Loss:0.0000
# Epoch:139,Loss:0.0000
# Epoch:140,Loss:0.0000
# Epoch:141,Loss:0.0000
# Epoch:142,Loss:0.0000
# Epoch:143,Loss:0.0000
# Epoch:144,Loss:0.0000
# Epoch:145,Loss:0.0000
# Epoch:146,Loss:0.0000
# Epoch:147,Loss:0.0000
# Epoch:148,Loss:0.0000
# Epoch:149,Loss:0.0000
# Epoch:150,Loss:0.0000
# Epoch:151,Loss:0.0000
# Epoch:152,Loss:0.0000
# Epoch:153,Loss:0.0000
# Epoch:154,Loss:0.0000
# Epoch:155,Loss:0.0000
# Epoch:156,Loss:0.0000
# Epoch:157,Loss:0.0000
# Epoch:158,Loss:0.0000
# Epoch:159,Loss:0.0000
# Epoch:160,Loss:0.0000
# Epoch:161,Loss:0.0000
# Epoch:162,Loss:0.0000
# Epoch:163,Loss:0.0000
# Epoch:164,Loss:0.0000
# Epoch:165,Loss:0.0000
# Epoch:166,Loss:0.0000
# Epoch:167,Loss:0.0000
# Epoch:168,Loss:0.0000
# Epoch:169,Loss:0.0000
# Epoch:170,Loss:0.0000
# Epoch:171,Loss:0.0000
# Epoch:172,Loss:0.0000
# Epoch:173,Loss:0.0000
# Epoch:174,Loss:0.0000
# Epoch:175,Loss:0.0000
# Epoch:176,Loss:0.0000
# Epoch:177,Loss:0.0000
# Epoch:178,Loss:0.0000
# Epoch:179,Loss:0.0000
# Epoch:180,Loss:0.0000
# Epoch:181,Loss:0.0000
# Epoch:182,Loss:0.0000
# Epoch:183,Loss:0.0000
# Epoch:184,Loss:0.0000
# Epoch:185,Loss:0.0000
# Epoch:186,Loss:0.0000
# Epoch:187,Loss:0.0000
# Epoch:188,Loss:0.0000
# Epoch:189,Loss:0.0000
# Epoch:190,Loss:0.0000
# Epoch:191,Loss:0.0000
# Epoch:192,Loss:0.0000
# Epoch:193,Loss:0.0000
# Epoch:194,Loss:0.0000
# Epoch:195,Loss:0.0000
# Epoch:196,Loss:0.0000
# Epoch:197,Loss:0.0000
# Epoch:198,Loss:0.0000
# Epoch:199,Loss:0.0000
# Epoch:200,Loss:0.0000
# erro =  0.5833333333333334
# acerto =  0.4166666666666667
# (40, 30)
# (40,)
# (50, 30)
# (50,)
# Input_Train torch.Size([4, 10, 30])
# Train_Labels torch.Size([4, 10, 1])
# Input_test torch.Size([5, 10, 30])
# test_Labels torch.Size([5, 10, 1])
# Epoch:1,Loss:0.0009
# Epoch:2,Loss:0.0003
# Epoch:3,Loss:0.0620
# Epoch:4,Loss:0.0136
# Epoch:5,Loss:0.1026
# Epoch:6,Loss:0.1524
# Epoch:7,Loss:0.0443
# Epoch:8,Loss:0.0942
# Epoch:9,Loss:0.0133
# Epoch:10,Loss:0.0095
# Epoch:11,Loss:0.0331
# Epoch:12,Loss:0.0043
# Epoch:13,Loss:0.0031
# Epoch:14,Loss:0.0016
# Epoch:15,Loss:0.0016
# Epoch:16,Loss:0.0019
# Epoch:17,Loss:0.0018
# Epoch:18,Loss:0.0012
# Epoch:19,Loss:0.0009
# Epoch:20,Loss:0.0007
# Epoch:21,Loss:0.0005
# Epoch:22,Loss:0.0003
# Epoch:23,Loss:0.0003
# Epoch:24,Loss:0.0002
# Epoch:25,Loss:0.0001
# Epoch:26,Loss:0.0001
# Epoch:27,Loss:0.0001
# Epoch:28,Loss:0.0001
# Epoch:29,Loss:0.0001
# Epoch:30,Loss:0.0001
# Epoch:31,Loss:0.0001
# Epoch:32,Loss:0.0001
# Epoch:33,Loss:0.0001
# Epoch:34,Loss:0.0001
# Epoch:35,Loss:0.0000
# Epoch:36,Loss:0.0000
# Epoch:37,Loss:0.0000
# Epoch:38,Loss:0.0000
# Epoch:39,Loss:0.0000
# Epoch:40,Loss:0.0000
# Epoch:41,Loss:0.0000
# Epoch:42,Loss:0.0000
# Epoch:43,Loss:0.0000
# Epoch:44,Loss:0.0000
# Epoch:45,Loss:0.0000
# Epoch:46,Loss:0.0000
# Epoch:47,Loss:0.0000
# Epoch:48,Loss:0.0000
# Epoch:49,Loss:0.0000
# Epoch:50,Loss:0.0000
# Epoch:51,Loss:0.0000
# Epoch:52,Loss:0.0000
# Epoch:53,Loss:0.0000
# Epoch:54,Loss:0.0000
# Epoch:55,Loss:0.0000
# Epoch:56,Loss:0.0000
# Epoch:57,Loss:0.0000
# Epoch:58,Loss:0.0000
# Epoch:59,Loss:0.0000
# Epoch:60,Loss:0.0000
# Epoch:61,Loss:0.0000
# Epoch:62,Loss:0.0000
# Epoch:63,Loss:0.0000
# Epoch:64,Loss:0.0000
# Epoch:65,Loss:0.0000
# Epoch:66,Loss:0.0000
# Epoch:67,Loss:0.0000
# Epoch:68,Loss:0.0000
# Epoch:69,Loss:0.0000
# Epoch:70,Loss:0.0000
# Epoch:71,Loss:0.0000
# Epoch:72,Loss:0.0000
# Epoch:73,Loss:0.0000
# Epoch:74,Loss:0.0000
# Epoch:75,Loss:0.0000
# Epoch:76,Loss:0.0000
# Epoch:77,Loss:0.0000
# Epoch:78,Loss:0.0000
# Epoch:79,Loss:0.0000
# Epoch:80,Loss:0.0000
# Epoch:81,Loss:0.0000
# Epoch:82,Loss:0.0000
# Epoch:83,Loss:0.0000
# Epoch:84,Loss:0.0000
# Epoch:85,Loss:0.0000
# Epoch:86,Loss:0.0000
# Epoch:87,Loss:0.0000
# Epoch:88,Loss:0.0000
# Epoch:89,Loss:0.0000
# Epoch:90,Loss:0.0000
# Epoch:91,Loss:0.0000
# Epoch:92,Loss:0.0000
# Epoch:93,Loss:0.0000
# Epoch:94,Loss:0.0000
# Epoch:95,Loss:0.0000
# Epoch:96,Loss:0.0000
# Epoch:97,Loss:0.0000
# Epoch:98,Loss:0.0000
# Epoch:99,Loss:0.0000
# Epoch:100,Loss:0.0000
# Epoch:101,Loss:0.0000
# Epoch:102,Loss:0.0000
# Epoch:103,Loss:0.0000
# Epoch:104,Loss:0.0000
# Epoch:105,Loss:0.0000
# Epoch:106,Loss:0.0000
# Epoch:107,Loss:0.0000
# Epoch:108,Loss:0.0000
# Epoch:109,Loss:0.0000
# Epoch:110,Loss:0.0000
# Epoch:111,Loss:0.0000
# Epoch:112,Loss:0.0000
# Epoch:113,Loss:0.0000
# Epoch:114,Loss:0.0000
# Epoch:115,Loss:0.0000
# Epoch:116,Loss:0.0000
# Epoch:117,Loss:0.0000
# Epoch:118,Loss:0.0000
# Epoch:119,Loss:0.0000
# Epoch:120,Loss:0.0000
# Epoch:121,Loss:0.0000
# Epoch:122,Loss:0.0000
# Epoch:123,Loss:0.0000
# Epoch:124,Loss:0.0000
# Epoch:125,Loss:0.0000
# Epoch:126,Loss:0.0000
# Epoch:127,Loss:0.0000
# Epoch:128,Loss:0.0000
# Epoch:129,Loss:0.0000
# Epoch:130,Loss:0.0000
# Epoch:131,Loss:0.0000
# Epoch:132,Loss:0.0000
# Epoch:133,Loss:0.0000
# Epoch:134,Loss:0.0000
# Epoch:135,Loss:0.0000
# Epoch:136,Loss:0.0000
# Epoch:137,Loss:0.0000
# Epoch:138,Loss:0.0000
# Epoch:139,Loss:0.0000
# Epoch:140,Loss:0.0000
# Epoch:141,Loss:0.0000
# Epoch:142,Loss:0.0000
# Epoch:143,Loss:0.0000
# Epoch:144,Loss:0.0000
# Epoch:145,Loss:0.0000
# Epoch:146,Loss:0.0000
# Epoch:147,Loss:0.0000
# Epoch:148,Loss:0.0000
# Epoch:149,Loss:0.0000
# Epoch:150,Loss:0.0000
# Epoch:151,Loss:0.0000
# Epoch:152,Loss:0.0000
# Epoch:153,Loss:0.0000
# Epoch:154,Loss:0.0000
# Epoch:155,Loss:0.0000
# Epoch:156,Loss:0.0000
# Epoch:157,Loss:0.0000
# Epoch:158,Loss:0.0000
# Epoch:159,Loss:0.0000
# Epoch:160,Loss:0.0000
# Epoch:161,Loss:0.0000
# Epoch:162,Loss:0.0000
# Epoch:163,Loss:0.0000
# Epoch:164,Loss:0.0000
# Epoch:165,Loss:0.0000
# Epoch:166,Loss:0.0000
# Epoch:167,Loss:0.0000
# Epoch:168,Loss:0.0000
# Epoch:169,Loss:0.0000
# Epoch:170,Loss:0.0000
# Epoch:171,Loss:0.0000
# Epoch:172,Loss:0.0000
# Epoch:173,Loss:0.0000
# Epoch:174,Loss:0.0000
# Epoch:175,Loss:0.0000
# Epoch:176,Loss:0.0000
# Epoch:177,Loss:0.0000
# Epoch:178,Loss:0.0000
# Epoch:179,Loss:0.0000
# Epoch:180,Loss:0.0000
# Epoch:181,Loss:0.0000
# Epoch:182,Loss:0.0000
# Epoch:183,Loss:0.0000
# Epoch:184,Loss:0.0000
# Epoch:185,Loss:0.0000
# Epoch:186,Loss:0.0000
# Epoch:187,Loss:0.0000
# Epoch:188,Loss:0.0000
# Epoch:189,Loss:0.0000
# Epoch:190,Loss:0.0000
# Epoch:191,Loss:0.0000
# Epoch:192,Loss:0.0000
# Epoch:193,Loss:0.0000
# Epoch:194,Loss:0.0000
# Epoch:195,Loss:0.0000
# Epoch:196,Loss:0.0000
# Epoch:197,Loss:0.0000
# Epoch:198,Loss:0.0000
# Epoch:199,Loss:0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4e0f3182c97d> in <module>
# ----> 1 eval_model(200)
#
# <ipython-input-20-f143f0623ee7> in eval_model(epochs)
#       9         #PATH_load='state_0_model.pt'
#      10         #model.load_state_dict(torch.load(PATH_load))
# ---> 11         treine(epochs)
#      12         erro,acerto = Eval_metric('test')
#      13         y1.append(erro)
#
# <ipython-input-11-94f35ac2d245> in treine(epochs)
#      12             O=O.float()
#      13             A=A.float()
# ---> 14             recon = model(O)
#      15             loss=torch.mean((recon-A)**2)
#      16             optimizer.zero_grad()
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-8-3c017700add8> in forward(self, x)
#      20         )
#      21     def forward(self, x):
# ---> 22         encoded = self.encoder(x)
#      23 #        print(np.shape(encoded))
#      24 #        print(np.shape(aux))
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1094         return result
#    1095
# -> 1096     def _call_impl(self, *input, **kwargs):
#    1097         forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1098         # If we don't have any hooks, we want to skip the rest of the logic in
#
# KeyboardInterrupt:

# %%
def eval_model(epochs_i, epochs_f):
    y1 = []
    y2 = []
    epochs = []
    x = np.linspace(0, 5, 5)
    for epoch in range(epochs_i, epochs_f, 20):
        Input, Output, Input_test, Output_test = gen_dataset(5)
        model = Autoencoder()
        PATH_load = 'state_0_model.pt'
        model.load_state_dict(torch.load(PATH_load))
        treine(epoch)
        epochs.append(epoch)
        erro, acerto = Eval_metric('test')
        size = np.shape(Input_test)[0]*np.shape(Input_test)[1]
        print(size)
        # s.exit()
        y1.append(erro/size)
        y2.append(acerto/size)
    return y1, y2, epochs


y1, y2, epochs = eval_model(20, 100)
# Out:
# (50, 30)
# (50,)
# (40, 30)
# (40,)
# Input_Train torch.Size([5, 10, 30])
# Train_Labels torch.Size([5, 10, 1])
# Input_test torch.Size([4, 10, 30])
# test_Labels torch.Size([4, 10, 1])
# Epoch:1,Loss:0.0268
# Epoch:2,Loss:0.0619
# Epoch:3,Loss:0.0328
# Epoch:4,Loss:0.0525
# Epoch:5,Loss:0.0219
# Epoch:6,Loss:0.0536
# Epoch:7,Loss:0.0212
# Epoch:8,Loss:0.0385
# Epoch:9,Loss:0.0294
# Epoch:10,Loss:0.0254
# Epoch:11,Loss:0.0344
# Epoch:12,Loss:0.0228
# Epoch:13,Loss:0.0263
# Epoch:14,Loss:0.0290
# Epoch:15,Loss:0.0222
# Epoch:16,Loss:0.0238
# Epoch:17,Loss:0.0257
# Epoch:18,Loss:0.0214
# Epoch:19,Loss:0.0226
# Epoch:20,Loss:0.0242
# erro =  0.625
# acerto =  0.375
# 40
# (50, 30)
# (50,)
# (40, 30)
# (40,)
# Input_Train torch.Size([5, 10, 30])
# Train_Labels torch.Size([5, 10, 1])
# Input_test torch.Size([4, 10, 30])
# test_Labels torch.Size([4, 10, 1])
# Epoch:1,Loss:0.0202
# Epoch:2,Loss:0.0209
# Epoch:3,Loss:0.0225
# Epoch:4,Loss:0.0193
# Epoch:5,Loss:0.0191
# Epoch:6,Loss:0.0214
# Epoch:7,Loss:0.0193
# Epoch:8,Loss:0.0177
# Epoch:9,Loss:0.0180
# Epoch:10,Loss:0.0175
# Epoch:11,Loss:0.0162
# Epoch:12,Loss:0.0171
# Epoch:13,Loss:0.0184
# Epoch:14,Loss:0.0151
# Epoch:15,Loss:0.0135
# Epoch:16,Loss:0.0170
# Epoch:17,Loss:0.0201
# Epoch:18,Loss:0.0128
# Epoch:19,Loss:0.0099
# Epoch:20,Loss:0.0168
# Epoch:21,Loss:0.0300
# Epoch:22,Loss:0.0207
# Epoch:23,Loss:0.0063
# Epoch:24,Loss:0.0076
# Epoch:25,Loss:0.0262
# Epoch:26,Loss:0.0382
# Epoch:27,Loss:0.0094
# Epoch:28,Loss:0.0057
# Epoch:29,Loss:0.0122
# Epoch:30,Loss:0.0532
# Epoch:31,Loss:0.0214
# Epoch:32,Loss:0.0049
# Epoch:33,Loss:0.0096
# Epoch:34,Loss:0.0327
# Epoch:35,Loss:0.0207
# Epoch:36,Loss:0.0035
# Epoch:37,Loss:0.0071
# Epoch:38,Loss:0.0332
# Epoch:39,Loss:0.0175
# Epoch:40,Loss:0.0030
# erro =  0.675
# acerto =  0.325
# 40
# (50, 30)
# (50,)
# (40, 30)
# (40,)
# Input_Train torch.Size([5, 10, 30])
# Train_Labels torch.Size([5, 10, 1])
# Input_test torch.Size([4, 10, 30])
# test_Labels torch.Size([4, 10, 1])
# Epoch:1,Loss:0.0086
# Epoch:2,Loss:0.0273
# Epoch:3,Loss:0.0073
# Epoch:4,Loss:0.0032
# Epoch:5,Loss:0.0121
# Epoch:6,Loss:0.0329
# Epoch:7,Loss:0.0027
# Epoch:8,Loss:0.0025
# Epoch:9,Loss:0.0204
# Epoch:10,Loss:0.0179
# Epoch:11,Loss:0.0017
# Epoch:12,Loss:0.0136
# Epoch:13,Loss:0.0041
# Epoch:14,Loss:0.0024
# Epoch:15,Loss:0.0149
# Epoch:16,Loss:0.0026
# Epoch:17,Loss:0.0020
# Epoch:18,Loss:0.0118
# Epoch:19,Loss:0.0074
# Epoch:20,Loss:0.0019
# Epoch:21,Loss:0.0370
# Epoch:22,Loss:0.0066
# Epoch:23,Loss:0.0083
# Epoch:24,Loss:0.0115
# Epoch:25,Loss:0.0109
# Epoch:26,Loss:0.0042
# Epoch:27,Loss:0.0049
# Epoch:28,Loss:0.0027
# Epoch:29,Loss:0.0025
# Epoch:30,Loss:0.0020
# Epoch:31,Loss:0.0017
# Epoch:32,Loss:0.0016
# Epoch:33,Loss:0.0015
# Epoch:34,Loss:0.0013
# Epoch:35,Loss:0.0012
# Epoch:36,Loss:0.0011
# Epoch:37,Loss:0.0010
# Epoch:38,Loss:0.0010
# Epoch:39,Loss:0.0010
# Epoch:40,Loss:0.0009
# Epoch:41,Loss:0.0008
# Epoch:42,Loss:0.0008
# Epoch:43,Loss:0.0007
# Epoch:44,Loss:0.0007
# Epoch:45,Loss:0.0007
# Epoch:46,Loss:0.0006
# Epoch:47,Loss:0.0006
# Epoch:48,Loss:0.0007
# Epoch:49,Loss:0.0006
# Epoch:50,Loss:0.0005
# Epoch:51,Loss:0.0007
# Epoch:52,Loss:0.0006
# Epoch:53,Loss:0.0005
# Epoch:54,Loss:0.0006
# Epoch:55,Loss:0.0005
# Epoch:56,Loss:0.0004
# Epoch:57,Loss:0.0005
# Epoch:58,Loss:0.0004
# Epoch:59,Loss:0.0004
# Epoch:60,Loss:0.0004
# erro =  0.675
# acerto =  0.325
# 40
# (50, 30)
# (50,)
# (40, 30)
# (40,)
# Input_Train torch.Size([5, 10, 30])
# Train_Labels torch.Size([5, 10, 1])
# Input_test torch.Size([4, 10, 30])
# test_Labels torch.Size([4, 10, 1])
# Epoch:1,Loss:0.0004
# Epoch:2,Loss:0.0003
# Epoch:3,Loss:0.0004
# Epoch:4,Loss:0.0004
# Epoch:5,Loss:0.0003
# Epoch:6,Loss:0.0003
# Epoch:7,Loss:0.0004
# Epoch:8,Loss:0.0003
# Epoch:9,Loss:0.0003
# Epoch:10,Loss:0.0003
# Epoch:11,Loss:0.0003
# Epoch:12,Loss:0.0002
# Epoch:13,Loss:0.0003
# Epoch:14,Loss:0.0003
# Epoch:15,Loss:0.0003
# Epoch:16,Loss:0.0002
# Epoch:17,Loss:0.0002
# Epoch:18,Loss:0.0003
# Epoch:19,Loss:0.0002
# Epoch:20,Loss:0.0002
# Epoch:21,Loss:0.0002
# Epoch:22,Loss:0.0002
# Epoch:23,Loss:0.0002
# Epoch:24,Loss:0.0002
# Epoch:25,Loss:0.0002
# Epoch:26,Loss:0.0002
# Epoch:27,Loss:0.0001
# Epoch:28,Loss:0.0001
# Epoch:29,Loss:0.0002
# Epoch:30,Loss:0.0002
# Epoch:31,Loss:0.0001
# Epoch:32,Loss:0.0001
# Epoch:33,Loss:0.0002
# Epoch:34,Loss:0.0001
# Epoch:35,Loss:0.0001
# Epoch:36,Loss:0.0001
# Epoch:37,Loss:0.0001
# Epoch:38,Loss:0.0001
# Epoch:39,Loss:0.0001
# Epoch:40,Loss:0.0001
# Epoch:41,Loss:0.0002
# Epoch:42,Loss:0.0001
# Epoch:43,Loss:0.0001
# Epoch:44,Loss:0.0001
# Epoch:45,Loss:0.0002
# Epoch:46,Loss:0.0001
# Epoch:47,Loss:0.0001
# Epoch:48,Loss:0.0001
# Epoch:49,Loss:0.0002
# Epoch:50,Loss:0.0001
# Epoch:51,Loss:0.0001
# Epoch:52,Loss:0.0001
# Epoch:53,Loss:0.0001
# Epoch:54,Loss:0.0001
# Epoch:55,Loss:0.0001
# Epoch:56,Loss:0.0001
# Epoch:57,Loss:0.0001
# Epoch:58,Loss:0.0001
# Epoch:59,Loss:0.0001
# Epoch:60,Loss:0.0001
# Epoch:61,Loss:0.0000
# Epoch:62,Loss:0.0001
# Epoch:63,Loss:0.0001
# Epoch:64,Loss:0.0001
# Epoch:65,Loss:0.0000
# Epoch:66,Loss:0.0000
# Epoch:67,Loss:0.0002
# Epoch:68,Loss:0.0001
# Epoch:69,Loss:0.0000
# Epoch:70,Loss:0.0000
# Epoch:71,Loss:0.0002
# Epoch:72,Loss:0.0001
# Epoch:73,Loss:0.0000
# Epoch:74,Loss:0.0001
# Epoch:75,Loss:0.0001
# Epoch:76,Loss:0.0000
# Epoch:77,Loss:0.0001
# Epoch:78,Loss:0.0000
# Epoch:79,Loss:0.0000
# Epoch:80,Loss:0.0000
# erro =  0.65
# acerto =  0.35
# 40

# %%
plt.plot(epochs, y1)
plt.xlabel('Epocas de treino')
plt.title('Erros')
plt.show()

# %%
plt.plot(epochs, y2)
plt.xlabel('Exemplos de treino')
plt.title('Acertos')
plt.show()
